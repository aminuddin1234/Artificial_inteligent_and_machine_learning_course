# %% [markdown]
# # supervised learning

# %% [markdown]
# Machine learning with data that have label

# %% [markdown]
# 1. Classification
#     - output has to belong a category
#
#
# 2. Regression
#     - output is value(number)

# %% [markdown]
# Has NO LABEL to learn from

# %% [markdown]
# # Unsupervised Learning

# %% [markdown]
# NO Label on that data to let machine identify the ciri2/detail yg ad kt data tersebut

# %% [markdown]
# ----

# %% [markdown]
# `linear regression`
#
# - use scatter plot

# %% [markdown]
# - `Y` dependent variables       ( Y depends on X?)
# - `X` independent variables

# %% [markdown]
# `Best Fit Lines` is  a line through teh data at which all the data points that are the closest they can be from line
