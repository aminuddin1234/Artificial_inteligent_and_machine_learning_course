# %% [markdown]
# [Explanation vis](https://mlu-explain.github.io/decision-tree/)
#
# - decision tree is a series of Yes/No
#
# - if u think about decision tree, think about hierarecy/brances
#
# - node is caring of condition

# %% [markdown]
# -----

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier,plot_tree


from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
titanic = sns.load_dataset('titanic')
titanic = pd.DataFrame(titanic)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
x,y = pd.factorize(titanic['survived'])
titanic['survived_code'] = x

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  survived_code
# 0      man        True  NaN  Southampton    no  False              0
# 1    woman       False    C    Cherbourg   yes  False              1
# 2    woman       False  NaN  Southampton   yes   True              1
# 3    woman       False    C  Southampton   yes  False              1
# 4      man        True  NaN  Southampton    no   True              0
# ..     ...         ...  ...          ...   ...    ...            ...
# 886    man        True  NaN  Southampton    no   True              0
# 887  woman       False    B  Southampton   yes   True              1
# 888  woman       False  NaN  Southampton    no  False              0
# 889    man        True    C    Cherbourg   yes   True              1
# 890    man        True  NaN   Queenstown    no   True              0
#
# [891 rows x 16 columns]

# %%
x = titanic[['fare']]
y = titanic['survived_code']

# %%
model_dt = DecisionTreeClassifier()
model_lr = LogisticRegression()

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, random_state= 42, test_size= 0.2)

model_dt.fit(x_train,y_train)
model_lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred_dt = model_dt.predict(x_test)
y_pred_lr = model_lr.predict(x_test)

# %%
# Very great report for model 

cr_dt = classification_report(y_test,y_pred_dt)         
cr_lr = classification_report(y_test,y_pred_lr)
print(cr_dt,cr_lr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.84      0.76       105
#            1       0.68      0.49      0.57        74
#
#     accuracy                           0.69       179
#    macro avg       0.69      0.66      0.66       179
# weighted avg       0.69      0.69      0.68       179
#                precision    recall  f1-score   support
#
#            0       0.64      0.95      0.76       105
#            1       0.77      0.23      0.35        74
#
#     accuracy                           0.65       179
#    macro avg       0.70      0.59      0.56       179
# weighted avg       0.69      0.65      0.59       179

# %%
titanic['fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 891, dtype: float64

# %%
pip install dtreeviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: dtreeviz in c:\users\user\appdata\roaming\python\python314\site-packages (2.2.2)
# Requirement already satisfied: graphviz>=0.9 in c:\users\user\appdata\roaming\python\python314\site-packages (from dtreeviz) (0.21)
# Requirement already satisfied: pandas in c:\users\user\appdata\roaming\python\python314\site-packages (from dtreeviz) (2.3.3)
# Requirement already satisfied: numpy in c:\users\user\appdata\roaming\python\python314\site-packages (from dtreeviz) (2.3.5)
# Requirement already satisfied: scikit-learn in c:\users\user\appdata\roaming\python\python314\site-packages (from dtreeviz) (1.8.0)
# Requirement already satisfied: matplotlib in c:\users\user\appdata\roaming\python\python314\site-packages (from dtreeviz) (3.10.8)
# Requirement already satisfied: colour in c:\users\user\appdata\roaming\python\python314\site-packages (from dtreeviz) (0.1.5)
# Requirement already satisfied: pytest in c:\users\user\appdata\roaming\python\python314\site-packages (from dtreeviz) (9.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\roaming\python\python314\site-packages (from matplotlib->dtreeviz) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\roaming\python\python314\site-packages (from matplotlib->dtreeviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\roaming\python\python314\site-packages (from matplotlib->dtreeviz) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\appdata\roaming\python\python314\site-packages (from matplotlib->dtreeviz) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python314\site-packages (from matplotlib->dtreeviz) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\user\appdata\roaming\python\python314\site-packages (from matplotlib->dtreeviz) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\user\appdata\roaming\python\python314\site-packages (from matplotlib->dtreeviz) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\roaming\python\python314\site-packages (from matplotlib->dtreeviz) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\roaming\python\python314\site-packages (from pandas->dtreeviz) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\roaming\python\python314\site-packages (from pandas->dtreeviz) (2025.3)
# Requirement already satisfied: colorama>=0.4 in c:\users\user\appdata\roaming\python\python314\site-packages (from pytest->dtreeviz) (0.4.6)
# Requirement already satisfied: iniconfig>=1.0.1 in c:\users\user\appdata\roaming\python\python314\site-packages (from pytest->dtreeviz) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\user\appdata\roaming\python\python314\site-packages (from pytest->dtreeviz) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in c:\users\user\appdata\roaming\python\python314\site-packages (from pytest->dtreeviz) (2.19.2)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\user\appdata\roaming\python\python314\site-packages (from scikit-learn->dtreeviz) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\user\appdata\roaming\python\python314\site-packages (from scikit-learn->dtreeviz) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\user\appdata\roaming\python\python314\site-packages (from scikit-learn->dtreeviz) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
plt.Figure(figsize=(25,12), dpi=300)
plot_tree(model_dt, 
          feature_names= titanic['fare'], 
          class_names=titanic['alive'], 
          max_depth=2,
           filled=True,
            rounded=True )
# Out:
# [Text(0.5, 0.875, '7.25 <= 10.481\ngini = 0.469\nsamples = 712\nvalue = [444, 268]\nclass = no'),
#  Text(0.25, 0.625, '7.25 <= 7.133\ngini = 0.321\nsamples = 274\nvalue = [219, 55]\nclass = no'),
#  Text(0.375, 0.75, 'True  '),
#  Text(0.125, 0.375, '7.25 <= 7.013\ngini = 0.114\nsamples = 33\nvalue = [31, 2]\nclass = no'),
#  Text(0.0625, 0.125, '\n  (...)  \n'),
#  Text(0.1875, 0.125, '\n  (...)  \n'),
#  Text(0.375, 0.375, '7.25 <= 7.883\ngini = 0.343\nsamples = 241\nvalue = [188, 53]\nclass = no'),
#  Text(0.3125, 0.125, '\n  (...)  \n'),
#  Text(0.4375, 0.125, '\n  (...)  \n'),
#  Text(0.75, 0.625, '7.25 <= 52.277\ngini = 0.5\nsamples = 438\nvalue = [225.0, 213.0]\nclass = no'),
#  Text(0.625, 0.75, '  False'),
#  Text(0.625, 0.375, '7.25 <= 39.644\ngini = 0.484\nsamples = 318\nvalue = [187, 131]\nclass = no'),
#  Text(0.5625, 0.125, '\n  (...)  \n'),
#  Text(0.6875, 0.125, '\n  (...)  \n'),
#  Text(0.875, 0.375, '7.25 <= 79.825\ngini = 0.433\nsamples = 120\nvalue = [38, 82]\nclass = yes'),
#  Text(0.8125, 0.125, '\n  (...)  \n'),
#  Text(0.9375, 0.125, '\n  (...)  \n')]

# %% [markdown]
# -----

# %% [markdown]
# ## Random Forest

# %% [markdown]
# - *Random forest use `ensemble` method*
#
#     - **Aggregate**
# - Bagging is creating multiple subsets of the
# ![image.png](attachment:image.png)

# %%
# For classification tasks
from sklearn.ensemble import RandomForestClassifier

# For regression tasks
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestClassifier

# 1. Initialize the model
# n_estimators is the number of trees in the forest
model = RandomForestClassifier(n_estimators=100, random_state=42)

# 2. Train the model
model.fit(x_train, y_train)

# 3. Make predictions
predict_rf = model.predict(x_test)

# %%
cr_rf = classification_report(y_test,predict_rf)
print(cr_rf)
print()
print()
print(cr_dt)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.82      0.76       105
#            1       0.67      0.53      0.59        74
#
#     accuracy                           0.70       179
#    macro avg       0.69      0.67      0.68       179
# weighted avg       0.69      0.70      0.69       179
#
#
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.84      0.76       105
#            1       0.68      0.49      0.57        74
#
#     accuracy                           0.69       179
#    macro avg       0.69      0.66      0.66       179
# weighted avg       0.69      0.69      0.68       179

# %%
from sklearn.neighbors import KNeighborsClassifier

# 1. Initialize the model
# n_neighbors is your 'k' value. 5 is the default.
knn = KNeighborsClassifier(n_neighbors=5)

# 2. Train the model
knn.fit(x_train, y_train)

# 3. Make a prediction
predict_knn = knn.predict(x_test)

# %%
cr_knn = classification_report(y_test,predict_knn)
print()
print(cr_knn)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.87      0.77       105
#            1       0.71      0.46      0.56        74
#
#     accuracy                           0.70       179
#    macro avg       0.70      0.66      0.66       179
# weighted avg       0.70      0.70      0.68       179
