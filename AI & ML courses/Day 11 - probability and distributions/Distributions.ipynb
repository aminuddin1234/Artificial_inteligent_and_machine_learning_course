# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#how many unique values do you see in all the column, and what can you infer
# what is the average bill amounts
# what is the average tip amount
# just find some new insights

# %%
#categorical data
df['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
df['size'].value_counts()

#dengan data ni sja kita boleh buat analyst
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
ave_bill = sum(df.total_bill) / len(df.total_bill)
ave_bill
# Out:
# 19.785942622950817

# %%
ave_tip = sum(df.tip) / len(df.tip)
ave_tip
# Out:
# 2.9982786885245902

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
plt.bar(sex,size, color = 'green')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 plt.bar(sex,size, color = 'green')
#
# NameError: name 'sex' is not defined

# %%
df['size'].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
y = df['size'].value_counts()
x = df['size']

sns.barplot(y=y,x=x)
# Out:
# <Axes: xlabel='size', ylabel='count'>

# %%
#this is better method
y = df['size'].value_counts() # This function for frequency distributions
x = df['size'].unique()  #Return all the classes part

sns.barplot(y=y,x=x)
# Out:
# <Axes: ylabel='count'>

# %%
# More simple method graph for frequency distribution
sns.histplot(df, x = 'size')
# Out:
# <Axes: xlabel='size', ylabel='Count'>

# %%
df['tip'].unique()
# Out:
# array([ 1.01,  1.66,  3.5 ,  3.31,  3.61,  4.71,  2.  ,  3.12,  1.96,
#         3.23,  1.71,  5.  ,  1.57,  3.  ,  3.02,  3.92,  1.67,  3.71,
#         3.35,  4.08,  2.75,  2.23,  7.58,  3.18,  2.34,  4.3 ,  1.45,
#         2.5 ,  2.45,  3.27,  3.6 ,  3.07,  2.31,  2.24,  2.54,  3.06,
#         1.32,  5.6 ,  6.  ,  2.05,  2.6 ,  5.2 ,  1.56,  4.34,  3.51,
#         1.5 ,  1.76,  6.73,  3.21,  1.98,  3.76,  2.64,  3.15,  2.47,
#         1.  ,  2.01,  2.09,  1.97,  3.14,  2.2 ,  1.25,  3.08,  4.  ,
#         2.71,  3.4 ,  1.83,  2.03,  5.17,  5.85,  3.25,  4.73,  3.48,
#         1.64,  4.06,  4.29,  2.55,  5.07,  1.8 ,  2.92,  1.68,  2.52,
#         4.2 ,  1.48,  2.18,  2.83,  6.7 ,  2.3 ,  1.36,  1.63,  1.73,
#         2.74,  5.14,  3.75,  2.61,  4.5 ,  1.61, 10.  ,  3.16,  5.15,
#         3.11,  3.55,  3.68,  5.65,  6.5 ,  4.19,  2.56,  2.02,  1.44,
#         3.41,  5.16,  9.  ,  1.1 ,  3.09,  1.92,  1.58,  2.72,  2.88,
#         3.39,  1.47,  1.17,  4.67,  5.92,  1.75])

# %%
sns.histplot(df, x = 'tip',fill=False)

plt.title('Frequency tip of given to the our workers')
plt.xlabel('Tip to workers')
plt.ylabel('frequency')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 sns.histplot(df, x = 'tip',fill=False)
#       3 plt.title('Frequency tip of given to the our workers')
#       4 plt.xlabel('Tip to workers')
#
# File c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\seaborn\distributions.py:1379, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1358 def histplot(
#    1359     data=None, *,
#    1360     # Vector variables
#    (...)   1376     **kwargs,
#    1377 ):
# -> 1379     p = _DistributionPlotter(
#    1380         data=data,
# ...

# %%
sns.barplot(data=df, y='size', x='sex', hue='smoker')
# Out:
# <Axes: xlabel='sex', ylabel='size'>

# %%
sns.relplot(data=df,x='day',y='total_bill',hue='sex')

# %% [markdown]
# - check how many rich or generous people come to our restaurant.
#
# - what is the size or rich people or high class people visiting place to buy

# %%
df['total_bill'].max()
# Out:
# np.float64(50.81)

# %%
df['total_bill'].min()
# Out:
# np.float64(3.07)

# %%
dftips = df['tip']
dftips
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
dfbill = df['total_bill']
dfbill
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
sns.histplot(df, x = 'smoker',fill=False,color= 'purple')
# Out:
# <Axes: xlabel='smoker', ylabel='Count'>

# %% [markdown]
# ## AI Ethics
# - data privacy - if the data is safe with researches -anonimity
# - data transparency

# %% [markdown]
# ## Distribution
#
# - how how the frequency of something is distributed
# - that if you take a **Sample size** of 100 people:
# - I want to know how tall the people of KL are, ages between 18 ~ 45
#
# 1. 7 feet
# 2. 5 feet
# 3. 3 feet
# -selecting a sample size:

# %%
data = {
    'name': ['idrees','hazirah','atirah','mel','nazri','ibrahim','amin'],
    'age': [29,2,25,25,25,25,25],
    'height':[185, 152, 163, 162,164,168,168],
    'gender':['m','f','f','f','m','m','m'],
    'ethnicity':['kashmiri','malay','malay','malay','malay','malay','malay']
}

# %%
df = pd.DataFrame(data)
df
# Out:
#       name  age  height gender ethnicity
# 0   idrees   25     185      m  kashmiri
# 1  hazirah   25     152      f     malay
# 2   atirah   25     163      f     malay
# 3      mel   25     162      f     malay
# 4    nazri   25     164      m     malay
# 5  ibrahim   25     168      m     malay
# 6     amin   25     168      m     malay

# %%
malay = df[df['ethnicity'] == 'malay']
malay
# Out:
#       name  age  height gender ethnicity
# 1  hazirah   25     152      f     malay
# 2   atirah   25     163      f     malay
# 3      mel   25     162      f     malay
# 4    nazri   25     164      m     malay
# 5  ibrahim   25     168      m     malay
# 6     amin   25     168      m     malay

# %%
sns.histplot(data=malay, x='height')
# Out:
# <Axes: xlabel='height', ylabel='Count'>

# %%
sns.barplot(data=data,x='name',y='height',color='green',fill=False)
# Out:
# <Axes: xlabel='name', ylabel='height'>

# %%
sns.histplot(data=data, x='height')
# Out:
# <Axes: xlabel='height', ylabel='Count'>

# %%
df3 = sns.load_dataset('tips')
df3
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Create these data frames
#1. only male
#2. tips above 6 dollar
#3.smokers dining on sunday

male = df3[df3['sex'] == 'Male' ]
male
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 1         10.34  1.66  Male     No  Sun  Dinner     3
# 2         21.01  3.50  Male     No  Sun  Dinner     3
# 3         23.68  3.31  Male     No  Sun  Dinner     2
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 6          8.77  2.00  Male     No  Sun  Dinner     2
# ..          ...   ...   ...    ...  ...     ...   ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2
# 239       29.03  5.92  Male     No  Sat  Dinner     3
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2
# 242       17.82  1.75  Male     No  Sat  Dinner     2
#
# [157 rows x 7 columns]

# %%
# 2
tips_6 = df3[df3['tip'] > 6.00 ]
tips_6
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3

# %%
sunday = df3[df3['day'] == 'Sun']
smoker = df3[df3['smoker'] == 'Yes']
dinner = df3[df3['time'] == 'Dinner']

# %%
newdf = df3[(df3['day'] == 'Sun') & (df3['smoker'] == 'Yes') & (df3['time'] == 'Dinner')]
newdf
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 164       17.51  3.00  Female    Yes  Sun  Dinner     2
# 172        7.25  5.15    Male    Yes  Sun  Dinner     2
# 173       31.85  3.18    Male    Yes  Sun  Dinner     2
# 174       16.82  4.00    Male    Yes  Sun  Dinner     2
# 175       32.90  3.11    Male    Yes  Sun  Dinner     2
# 176       17.89  2.00    Male    Yes  Sun  Dinner     2
# 177       14.48  2.00    Male    Yes  Sun  Dinner     2
# 178        9.60  4.00  Female    Yes  Sun  Dinner     2
# 179       34.63  3.55    Male    Yes  Sun  Dinner     2
# 180       34.65  3.68    Male    Yes  Sun  Dinner     4
# 181       23.33  5.65    Male    Yes  Sun  Dinner     2
# 182       45.35  3.50    Male    Yes  Sun  Dinner     3
# 183       23.17  6.50    Male    Yes  Sun  Dinner     4
# 184       40.55  3.00    Male    Yes  Sun  Dinner     2
# 186       20.90  3.50  Female    Yes  Sun  Dinner     3
# 187       30.46  2.00    Male    Yes  Sun  Dinner     5
# ...
