# %% [markdown]
# probability
# - likehood of something
# - Chances of something to happen
# - ML - machine to give outputs (any kind of machine). Yes or No
# - not just output but its decision
# - machine calculated the possibility of an answers
# - confidence
# - ML models calculate possibilities
# - how they calculate these. probabilities and distributions
# -  0 <= probability <= 1
#
# - algorithm - is sequences of steps
#
# ## formula =
# - probability = Number of favorable outcomes / number of possible outcomes
# - 0 is imposible, 1 is certain
#
# ## Dependant event
# like we play cards and then take the cards out n still playing with remaining cards.
