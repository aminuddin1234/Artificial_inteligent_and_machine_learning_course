# %%
#Import dataset
#run method that we learnt value count, unique on species column
#Create a new df object, without species column

# %%
import pandas as pd

# %%
df3 = pd.read_csv('iris.csv')
df3
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
print(df3.value_counts())
print(df3['petal_length'].unique())
# Out:
# sepal_length  sepal_width  petal_length  petal_width  species
# 4.9           3.1          1.5           0.1          setosa       3
# 5.8           2.7          5.1           1.9          virginica    2
# 4.3           3.0          1.1           0.1          setosa       1
# 4.4           3.2          1.3           0.2          setosa       1
# 4.5           2.3          1.3           0.3          setosa       1
#                                                                   ..
# 7.7           2.6          6.9           2.3          virginica    1
#               2.8          6.7           2.0          virginica    1
#               3.0          6.1           2.3          virginica    1
#               3.8          6.7           2.2          virginica    1
# 7.9           3.8          6.4           2.0          virginica    1
# Name: count, Length: 147, dtype: int64
# [1.4 1.3 1.5 1.7 1.6 1.1 1.2 1.  1.9 4.7 4.5 4.9 4.  4.6 3.3 3.9 3.5 4.2
# ...

# %%
df3['iris_without_species'] =pd.Series([1.3,4.2,3.3])

# %%
new_iris = df3.drop('species', axis=1)
new_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  \
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
#      iris_without_species
# 0                     1.3
# 1                     4.2
# 2                     3.3
# 3                     NaN
# 4                     NaN
# ..                    ...
# 145                   NaN
# 146                   NaN
# ...

# %%
new_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  iris_without_species
# 0           5.1          3.5           1.4          0.2                   1.3
# 1           4.9          3.0           1.4          0.2                   4.2
# 2           4.7          3.2           1.3          0.2                   3.3
# 3           4.6          3.1           1.5          0.2                   NaN
# 4           5.0          3.6           1.4          0.2                   NaN

# %%
new_iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  \
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
#      iris_without_species
# 145                   NaN
# 146                   NaN
# 147                   NaN
# 148                   NaN
# 149                   NaN

# %%
new_iris_del = new_iris.drop(["sepal_length",'sepal_width','petal_length','petal_width'],axis=1)
new_iris_del
# Out:
#      iris_without_species
# 0                     1.3
# 1                     4.2
# 2                     3.3
# 3                     NaN
# 4                     NaN
# ..                    ...
# 145                   NaN
# 146                   NaN
# 147                   NaN
# 148                   NaN
# 149                   NaN
#
# [150 rows x 1 columns]

# %%
print(type(new_iris_del))   ### type jdi (output) sbb single table ja .. dia x jdi byk table .. klau byk table jdi output lain
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
new_iris = df3.drop('species', axis=1)
new_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  \
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
#      iris_without_species
# 0                     1.3
# 1                     4.2
# 2                     3.3
# 3                     NaN
# 4                     NaN
# ..                    ...
# 145                   NaN
# 146                   NaN
# ...

# %%
#calculated area
sepalarea = new_iris[['sepal_length','sepal_width']]
sepalarea.head()
# Out:
#    sepal_length  sepal_width
# 0           5.1          3.5
# 1           4.9          3.0
# 2           4.7          3.2
# 3           4.6          3.1
# 4           5.0          3.6

# %%
sepalarea = new_iris['sepal_length']
sepalarea.head()
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# Name: sepal_length, dtype: float64

# %%
df3
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
petalarea = df3['petal_length'] * df3['petal_width']   #boleh kira untuk mna2 column
petalarea.head()
# Out:
# 0    0.28
# 1    0.28
# 2    0.26
# 3    0.30
# 4    0.28
# dtype: float64

# %%
sepalarea = df3['sepal_length'] * df3['sepal_width']   #boleh kira untuk mna2 column
sepalarea.head()
# Out:
# 0    17.85
# 1    14.70
# 2    15.04
# 3    14.26
# 4    18.00
# dtype: float64

# %%
df3['sepal_area'] = sepalarea
df3.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  sepal_area
# 0           5.1          3.5           1.4          0.2  setosa       17.85
# 1           4.9          3.0           1.4          0.2  setosa       14.70
# 2           4.7          3.2           1.3          0.2  setosa       15.04
# 3           4.6          3.1           1.5          0.2  setosa       14.26
# 4           5.0          3.6           1.4          0.2  setosa       18.00

# %%
df3['petal_area'] = petalarea
df3.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  sepal_area  \
# 0           5.1          3.5           1.4          0.2  setosa       17.85
# 1           4.9          3.0           1.4          0.2  setosa       14.70
# 2           4.7          3.2           1.3          0.2  setosa       15.04
# 3           4.6          3.1           1.5          0.2  setosa       14.26
# 4           5.0          3.6           1.4          0.2  setosa       18.00
#
#    petal_area
# 0        0.28
# 1        0.28
# 2        0.26
# 3        0.30
# 4        0.28

# %%
new_table = new_iris.drop('iris_without_species',axis=1)
new_table.head(50)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  sepal_area  \
# 0            5.1          3.5           1.4          0.2       17.85
# 1            4.9          3.0           1.4          0.2       14.70
# 2            4.7          3.2           1.3          0.2       15.04
# 3            4.6          3.1           1.5          0.2       14.26
# 4            5.0          3.6           1.4          0.2       18.00
# 5            5.4          3.9           1.7          0.4       21.06
# 6            4.6          3.4           1.4          0.3       15.64
# 7            5.0          3.4           1.5          0.2       17.00
# 8            4.4          2.9           1.4          0.2       12.76
# 9            4.9          3.1           1.5          0.1       15.19
# 10           5.4          3.7           1.5          0.2       19.98
# 11           4.8          3.4           1.6          0.2       16.32
# 12           4.8          3.0           1.4          0.1       14.40
# ...

# %%
#filter out parts of dataframe using pandas
# Q1 : only part of new_table value of sepal_area is > 14

largeflowers = new_table[new_table['sepal_area'] > 15]
largeflowers.head(10)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  sepal_area  \
# 0            5.1          3.5           1.4          0.2       17.85
# 2            4.7          3.2           1.3          0.2       15.04
# 4            5.0          3.6           1.4          0.2       18.00
# 5            5.4          3.9           1.7          0.4       21.06
# 6            4.6          3.4           1.4          0.3       15.64
# 7            5.0          3.4           1.5          0.2       17.00
# 9            4.9          3.1           1.5          0.1       15.19
# 10           5.4          3.7           1.5          0.2       19.98
# 11           4.8          3.4           1.6          0.2       16.32
# 14           5.8          4.0           1.2          0.2       23.20
#
#     petal_area
# 0         0.28
# 2         0.26
# 4         0.28
# 5         0.68
# 6         0.42
# 7         0.30
# 9         0.15
# 10        0.30
# 11        0.32
# 14        0.24

# %%
## How many large flowers we have in new_table dataset
#how many flowers have a  sepal area of exactly in

largeflowers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 120 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  120 non-null    float64
#  1   sepal_width   120 non-null    float64
#  2   petal_length  120 non-null    float64
#  3   petal_width   120 non-null    float64
#  4   sepal_area    120 non-null    float64
#  5   petal_area    120 non-null    float64
# dtypes: float64(6)
# memory usage: 6.6 KB

# %%
largeflowers2 = new_table[new_table['sepal_area'] > 16]
largeflowers2.head(10)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  sepal_area  \
# 0            5.1          3.5           1.4          0.2       17.85
# 4            5.0          3.6           1.4          0.2       18.00
# 5            5.4          3.9           1.7          0.4       21.06
# 7            5.0          3.4           1.5          0.2       17.00
# 10           5.4          3.7           1.5          0.2       19.98
# 11           4.8          3.4           1.6          0.2       16.32
# 14           5.8          4.0           1.2          0.2       23.20
# 15           5.7          4.4           1.5          0.4       25.08
# 16           5.4          3.9           1.3          0.4       21.06
# 17           5.1          3.5           1.4          0.3       17.85
#
#     petal_area
# 0         0.28
# 4         0.28
# 5         0.68
# 7         0.30
# 10        0.30
# 11        0.32
# 14        0.24
# 15        0.60
# 16        0.52
# 17        0.42

# %%
largeflowers2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  101 non-null    float64
#  1   sepal_width   101 non-null    float64
#  2   petal_length  101 non-null    float64
#  3   petal_width   101 non-null    float64
#  4   sepal_area    101 non-null    float64
#  5   petal_area    101 non-null    float64
# dtypes: float64(6)
# memory usage: 5.5 KB

# %%
# sorting values by something
sortedtargetflowers = largeflowers2.sort_values(by='sepal_area',ascending=False)
largestflowers = sortedtargetflowers
largestflowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  sepal_area  \
# 131           7.9          3.8           6.4          2.0       30.02
# 117           7.7          3.8           6.7          2.2       29.26
# 109           7.2          3.6           6.1          2.5       25.92
# 15            5.7          4.4           1.5          0.4       25.08
# 14            5.8          4.0           1.2          0.2       23.20
# ..            ...          ...           ...          ...         ...
# 24            4.8          3.4           1.9          0.2       16.32
# 64            5.6          2.9           3.6          1.3       16.24
# 114           5.8          2.8           5.1          2.4       16.24
# 83            6.0          2.7           5.1          1.6       16.20
# 84            5.4          3.0           4.5          1.5       16.20
#
#      petal_area
# 131       12.80
# 117       14.74
# 109       15.25
# 15         0.60
# 14         0.24
# ..          ...
# ...

# %%
df3.to_csv('Flowers_Visualization.csv',index=False)

# %%
largeflowers.to_csv('largeflowers.csv',index= False)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
arealargestflowers = largestflowers['sepal_area'].max()
arealargestflowers
# Out:
# np.float64(30.02)

# %%
arealargestflowers = largestflowers['sepal_area'].min()
arealargestflowers
# Out:
# np.float64(16.200000000000003)

# %%
arealargestflowers = largestflowers['sepal_area']
arealargestflowers
# Out:
# 131    30.02
# Name: sepal_area, dtype: float64

# %%
type(largestflowers)
# Out:
# pandas.core.series.Series
