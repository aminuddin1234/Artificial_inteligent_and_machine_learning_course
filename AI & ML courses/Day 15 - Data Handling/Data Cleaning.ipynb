# %%
data = [
    {"Transaction ID": 1001, "Customer Name": "Alice Smith", "Email": "alice@example.com", "Product": "Laptop", "Quantity": 1, "Price": 1200.00, "Purchase Date": "2024-09-15", "Delivery Status": True},
    {"Transaction ID": 1002, "Customer Name": "Bob Jones", "Email": None, "Product": "Headphones", "Quantity": 2, "Price": 150.00, "Purchase Date": "2024-09-16", "Delivery Status": True},
    {"Transaction ID": 1003, "Customer Name": "Charlie Johnson", "Email": "charlie#example.com", "Product": "Smartphone", "Quantity": 1, "Price": 800.00, "Purchase Date": "16/09/2024", "Delivery Status": True},
    {"Transaction ID": 1004, "Customer Name": "David Lee", "Email": "david.lee@example.com", "Product": "Laptop", "Quantity": 1, "Price": 120000.00, "Purchase Date": "2024-09-17", "Delivery Status": False},
    {"Transaction ID": 1005, "Customer Name": "Eve Martinez", "Email": "eve.martinez@example.com", "Product": "Smartwatch", "Quantity": 3, "Price": None, "Purchase Date": "17th Sep 2024", "Delivery Status": True},
    {"Transaction ID": 1006, "Customer Name": "Frank Wright", "Email": None, "Product": "Tablet", "Quantity": None, "Price": 600.00, "Purchase Date": "2024-09-18", "Delivery Status": False},
    {"Transaction ID": 1007, "Customer Name": "Grace Lee", "Email": "grace.lee@example.com", "Product": "Laptop", "Quantity": 1, "Price": 1200.00, "Purchase Date": "2024-09-19", "Delivery Status": True},
    {"Transaction ID": 1008, "Customer Name": "Hank Brown", "Email": "hank.brown@example.com", "Product": "Monitor", "Quantity": 2, "Price": 300.00, "Purchase Date": "09/19/2024", "Delivery Status": True},
    {"Transaction ID": 1009, "Customer Name": "Ivy Thompson", "Email": None, "Product": "Keyboard", "Quantity": 2, "Price": 100.00, "Purchase Date": "2024/09/20", "Delivery Status": False},
    {"Transaction ID": 1010, "Customer Name": "Jack Davis", "Email": "jack@example.com", "Product": "Mouse", "Quantity": 5, "Price": 50.00, "Purchase Date": "2024-09-21", "Delivery Status": True},
    {"Transaction ID": 1011, "Customer Name": "Alice Smith", "Email": "alice@example.com", "Product": "Laptop", "Quantity": 1, "Price": 1200.00, "Purchase Date": "2024-09-15", "Delivery Status": True},  # Duplicate entry
    {"Transaction ID": 1012, "Customer Name": "Kurt Evans", "Email": "kurt.evans@example.com", "Product": "Smartwatch", "Quantity": -1, "Price": 200.00, "Purchase Date": "2024-09-22", "Delivery Status": True},  # Outlier quantity
    {"Transaction ID": 1013, "Customer Name": "Liam Adams", "Email": "liam.adams@example.com", "Product": "Headphones", "Quantity": 2, "Price": 150.00, "Purchase Date": "2024-09-23", "Delivery Status": False},
    {"Transaction ID": 1014, "Customer Name": "Mia Clark", "Email": "mia.clark@example.com", "Product": None, "Quantity": 1, "Price": 0, "Purchase Date": "2024-09-24", "Delivery Status": True},  # Price anomaly
    {"Transaction ID": 1015, "Customer Name": "Nina Turner", "Email": None, "Product": "Tablet", "Quantity": 1, "Price": 600.00, "Purchase Date": "24-09-2024", "Delivery Status": True},
    {"Transaction ID": 1016, "Customer Name": "Oscar Harris", "Email": "oscar.harris@example.com", "Product": "Laptop", "Quantity": 2, "Price": 1200.00, "Purchase Date": "2024-09-25", "Delivery Status": True},
    {"Transaction ID": 1017, "Customer Name": "Paul Young", "Email": "paulyoung", "Product": "Monitor", "Quantity": 2, "Price": 300.00, "Purchase Date": "09/25/2024", "Delivery Status": True},
    {"Transaction ID": 1018, "Customer Name": "Quinn Lopez", "Email": None, "Product": "Smartphone", "Quantity": 1, "Price": 800.00, "Purchase Date": "2024-09-26", "Delivery Status": False},
    {"Transaction ID": 1019, "Customer Name": "Rachel Scott", "Email": "rachel.scott@example.com", "Product": "Keyboard", "Quantity": 2, "Price": 100000.00, "Purchase Date": "2024-09-27", "Delivery Status": True},
    {"Transaction ID": 1020, "Customer Name": "Steve King", "Email": "steve.king@example.com", "Product": "Mouse", "Quantity": None, "Price": 50.00, "Purchase Date": "2024-09-28", "Delivery Status": True},
]

# %%
type(data)
# Out:
# list

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction ID   20 non-null     int64
#  1   Customer Name    20 non-null     object
#  2   Email            15 non-null     object
#  3   Product          19 non-null     object
#  4   Quantity         18 non-null     float64
#  5   Price            19 non-null     float64
#  6   Purchase Date    20 non-null     object
#  7   Delivery Status  20 non-null     bool
# dtypes: bool(1), float64(2), int64(1), object(4)
# memory usage: 1.2+ KB

# %%
df
# Out:
#     Transaction ID    Customer Name                     Email     Product  \
# 0             1001      Alice Smith         alice@example.com      Laptop
# 1             1002        Bob Jones                      None  Headphones
# 2             1003  Charlie Johnson       charlie#example.com  Smartphone
# 3             1004        David Lee     david.lee@example.com      Laptop
# 4             1005     Eve Martinez  eve.martinez@example.com  Smartwatch
# 5             1006     Frank Wright                      None      Tablet
# 6             1007        Grace Lee     grace.lee@example.com      Laptop
# 7             1008       Hank Brown    hank.brown@example.com     Monitor
# 8             1009     Ivy Thompson                      None    Keyboard
# 9             1010       Jack Davis          jack@example.com       Mouse
# 10            1011      Alice Smith         alice@example.com      Laptop
# 11            1012       Kurt Evans    kurt.evans@example.com  Smartwatch
# 12            1013       Liam Adams    liam.adams@example.com  Headphones
# 13            1014        Mia Clark     mia.clark@example.com        None
# 14            1015      Nina Turner                      None      Tablet
# 15            1016     Oscar Harris  oscar.harris@example.com      Laptop
# 16            1017       Paul Young                 paulyoung     Monitor
# 17            1018      Quinn Lopez                      None  Smartphone
# 18            1019     Rachel Scott  rachel.scott@example.com    Keyboard
# 19            1020       Steve King    steve.king@example.com       Mouse
#
#     Quantity     Price  Purchase Date  Delivery Status
# 0        1.0    1200.0     2024-09-15             True
# 1        2.0     150.0     2024-09-16             True
# 2        1.0     800.0     16/09/2024             True
# 3        1.0  120000.0     2024-09-17            False
# 4        3.0       NaN  17th Sep 2024             True
# 5        NaN     600.0     2024-09-18            False
# 6        1.0    1200.0     2024-09-19             True
# 7        2.0     300.0     09/19/2024             True
# 8        2.0     100.0     2024/09/20            False
# 9        5.0      50.0     2024-09-21             True
# 10       1.0    1200.0     2024-09-15             True
# 11      -1.0     200.0     2024-09-22             True
# 12       2.0     150.0     2024-09-23            False
# 13       1.0       0.0     2024-09-24             True
# 14       1.0     600.0     24-09-2024             True
# 15       2.0    1200.0     2024-09-25             True
# 16       2.0     300.0     09/25/2024             True
# 17       1.0     800.0     2024-09-26            False
# 18       2.0  100000.0     2024-09-27             True
# 19       NaN      50.0     2024-09-28             True

# %%
dfx = df.dropna()

# %%
dfx
z_scores = stats.zscore(dfx['Price'])
z_scores
# Out:
# array([-0.43177538, -0.44154222,  2.46897385, -0.43177538, -0.45375076,
#        -0.45985503, -0.43177538, -0.45619246, -0.45741332, -0.43177538,
#        -0.45375076,  1.98063223])

# %%
threshold = 1.5
# -3 < z <3
new_x = dfx[ (-threshold < z_scores) & (z_scores < threshold) ]
new_x
# Out:
#     Transaction ID    Customer Name                     Email     Product  \
# 0             1001      Alice Smith         alice@example.com      Laptop
# 2             1003  Charlie Johnson       charlie#example.com  Smartphone
# 6             1007        Grace Lee     grace.lee@example.com      Laptop
# 7             1008       Hank Brown    hank.brown@example.com     Monitor
# 9             1010       Jack Davis          jack@example.com       Mouse
# 10            1011      Alice Smith         alice@example.com      Laptop
# 11            1012       Kurt Evans    kurt.evans@example.com  Smartwatch
# 12            1013       Liam Adams    liam.adams@example.com  Headphones
# 15            1016     Oscar Harris  oscar.harris@example.com      Laptop
# 16            1017       Paul Young                 paulyoung     Monitor
#
#     Quantity   Price Purchase Date  Delivery Status
# 0        1.0  1200.0    2024-09-15             True
# 2        1.0   800.0    16/09/2024             True
# 6        1.0  1200.0    2024-09-19             True
# 7        2.0   300.0    09/19/2024             True
# 9        5.0    50.0    2024-09-21             True
# 10       1.0  1200.0    2024-09-15             True
# 11      -1.0   200.0    2024-09-22             True
# 12       2.0   150.0    2024-09-23            False
# 15       2.0  1200.0    2024-09-25             True
# 16       2.0   300.0    09/25/2024             True

# %%
sns.boxplot(new_x['Price'])
# Out:
# <Axes: ylabel='Price'>

# %%
df.describe(include='all')
# Out:
#         Transaction ID Customer Name              Email Product   Quantity  \
# count         20.00000            20                 15      19  18.000000
# unique             NaN            19                 14       8        NaN
# top                NaN   Alice Smith  alice@example.com  Laptop        NaN
# freq               NaN             2                  2       5        NaN
# mean        1010.50000           NaN                NaN     NaN   1.611111
# std            5.91608           NaN                NaN     NaN   1.195033
# min         1001.00000           NaN                NaN     NaN  -1.000000
# 25%         1005.75000           NaN                NaN     NaN   1.000000
# 50%         1010.50000           NaN                NaN     NaN   1.500000
# 75%         1015.25000           NaN                NaN     NaN   2.000000
# max         1020.00000           NaN                NaN     NaN   5.000000
#
#               Price Purchase Date Delivery Status
# count     19.000000            20              20
# unique          NaN            19               2
# top             NaN    2024-09-15            True
# freq            NaN             2              15
# mean     536.842105           NaN             NaN
# std      472.241142           NaN             NaN
# min        0.000000           NaN             NaN
# 25%      125.000000           NaN             NaN
# 50%      300.000000           NaN             NaN
# 75%     1000.000000           NaN             NaN
# max     1200.000000           NaN             NaN

# %%
df.sample(5) # this will take random sample
# Out:
#     Transaction ID Customer Name                   Email     Product  \
# 6             1007     Grace Lee   grace.lee@example.com      Laptop
# 11            1012    Kurt Evans  kurt.evans@example.com  Smartwatch
# 16            1017    Paul Young               paulyoung     Monitor
# 0             1001   Alice Smith       alice@example.com      Laptop
# 12            1013    Liam Adams  liam.adams@example.com  Headphones
#
#     Quantity   Price Purchase Date  Delivery Status
# 6        1.0  1200.0    2024-09-19             True
# 11      -1.0   200.0    2024-09-22             True
# 16       2.0   300.0    09/25/2024             True
# 0        1.0  1200.0    2024-09-15             True
# 12       2.0   150.0    2024-09-23            False

# %%
df.isnull() # this will run all the data set and ask every row and column and ask 'empty or not'
# Out:
#     Transaction ID  Customer Name  Email  Product  Quantity  Price  \
# 0            False          False  False    False     False  False
# 1            False          False   True    False     False  False
# 2            False          False  False    False     False  False
# 3            False          False  False    False     False  False
# 4            False          False  False    False     False   True
# 5            False          False   True    False      True  False
# 6            False          False  False    False     False  False
# 7            False          False  False    False     False  False
# 8            False          False   True    False     False  False
# 9            False          False  False    False     False  False
# 10           False          False  False    False     False  False
# 11           False          False  False    False     False  False
# 12           False          False  False    False     False  False
# 13           False          False  False     True     False  False
# 14           False          False   True    False     False  False
# 15           False          False  False    False     False  False
# 16           False          False  False    False     False  False
# 17           False          False   True    False     False  False
# 18           False          False  False    False     False  False
# 19           False          False  False    False      True  False
#
#     Purchase Date  Delivery Status
# 0           False            False
# 1           False            False
# 2           False            False
# 3           False            False
# 4           False            False
# 5           False            False
# 6           False            False
# 7           False            False
# 8           False            False
# 9           False            False
# 10          False            False
# 11          False            False
# 12          False            False
# 13          False            False
# 14          False            False
# 15          False            False
# 16          False            False
# 17          False            False
# 18          False            False
# 19          False            False

# %%
countnull = df.isnull().sum()

# %%
import seaborn as sns
sns.barplot(data=countnull)
plt.xticks(rotation = 45, horizontalalignment='right', fontsize=8)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'Transaction ID'),
#   Text(1, 0, 'Customer Name'),
#   Text(2, 0, 'Email'),
#   Text(3, 0, 'Product'),
#   Text(4, 0, 'Quantity'),
#   Text(5, 0, 'Price'),
#   Text(6, 0, 'Purchase Date'),
#   Text(7, 0, 'Delivery Status')])

# %%
for col in df.columns:
    missing = df[col].isnull().sum()
    total = len(df)
    bar = '()' * int((missing/total)*20)
    print(f'{col:15} {missing}/{total} missing {bar}')
# Out:
# Transaction ID  0/20 missing
# Customer Name   0/20 missing
# Email           5/20 missing ()()()()()
# Product         1/20 missing ()
# Quantity        2/20 missing ()()
# Price           1/20 missing ()
# Purchase Date   0/20 missing
# Delivery Status 0/20 missing

# %%
countnull.values
#len(df)
#missing
# Out:
# array([0, 0, 5, 1, 2, 1, 0, 0])

# %%
for i in countnull:  #simple visualization
    missing = countnull.values
    total = len(df)
    bar = '()' * int(missing[i] + 1)
    print(f'{countnull.index[i]:17} missing: {bar}')
# Out:
# Transaction ID    missing: ()
# Transaction ID    missing: ()
# Price             missing: ()()
# Customer Name     missing: ()
# Email             missing: ()()()()()()
# Customer Name     missing: ()
# Transaction ID    missing: ()
# Transaction ID    missing: ()

# %%
x = 8.354345
y = 9.123545
print(f'{x:.2f} missing: {y:.5f}')   #.2f is use for round numbers
# Out:
# 8.35 missing: 9.12355

# %%
df.head()
# Out:
#    Transaction ID    Customer Name                     Email     Product  \
# 0            1001      Alice Smith         alice@example.com      Laptop
# 1            1002        Bob Jones                      None  Headphones
# 2            1003  Charlie Johnson       charlie#example.com  Smartphone
# 3            1004        David Lee     david.lee@example.com      Laptop
# 4            1005     Eve Martinez  eve.martinez@example.com  Smartwatch
#
#    Quantity   Price  Purchase Date  Delivery Status
# 0       1.0  1200.0     2024-09-15             True
# 1       2.0   150.0     2024-09-16             True
# 2       1.0   800.0     16/09/2024             True
# 3       1.0  1200.0     2024-09-17            False
# 4       3.0     NaN  17th Sep 2024             True

# %% [markdown]
# # duplicates values

# %%
playdata = [
    {"Transaction ID": 1001, "Customer Name": "Alice Smith", "Email": "alice@example.com", "Product": "Laptop", "Quantity": 1, "Price": 1200.00, "Purchase Date": "2024-09-15", "Delivery Status": True},
    {"Transaction ID": 1001, "Customer Name": "Alice Smith", "Email": "alice@example.com", "Product": "Laptop", "Quantity": 1, "Price": 1200.00, "Purchase Date": "2024-09-15", "Delivery Status": True},
    {"Transaction ID": 1001, "Customer Name": "Alice Smith", "Email": "alice@example.com", "Product": "Laptop", "Quantity": 1, "Price": 1200.00, "Purchase Date": "2024-09-15", "Delivery Status": True},
    {"Transaction ID": 1001, "Customer Name": "Alice Smith", "Email": "alice@example.com", "Product": "Laptop", "Quantity": 1, "Price": 1200.00, "Purchase Date": "2024-09-15", "Delivery Status": True},
    {"Transaction ID": 1002, "Customer Name": "Bob Jones", "Email": None, "Product": "Headphones", "Quantity": 2, "Price": 150.00, "Purchase Date": "2024-09-16", "Delivery Status": True},
    {"Transaction ID": 1003, "Customer Name": "Charlie Johnson", "Email": "charlie#example.com", "Product": "Smartphone", "Quantity": 1, "Price": 800.00, "Purchase Date": "16/09/2024", "Delivery Status": True},
    {"Transaction ID": 1004, "Customer Name": "David Lee", "Email": "david.lee@example.com", "Product": "Laptop", "Quantity": 1, "Price": 1200.00, "Purchase Date": "2024-09-17", "Delivery Status": False},
    {"Transaction ID": 1005, "Customer Name": "Eve Martinez", "Email": "eve.martinez@example.com", "Product": "Smartwatch", "Quantity": 3, "Price": 800.00, "Purchase Date": "17th Sep 2024", "Delivery Status": True},
    {"Transaction ID": 1006, "Customer Name": "Frank Wright", "Email": None, "Product": "Tablet", "Quantity": None, "Price": 600.00, "Purchase Date": "2024-09-18", "Delivery Status": False},
    {"Transaction ID": 1007, "Customer Name": "Grace Lee", "Email": "grace.lee@example.com", "Product": "Laptop", "Quantity": 1, "Price": 12000, "Purchase Date": "2024-09-19", "Delivery Status": True},
    {"Transaction ID": 1008, "Customer Name": "Hank Brown", "Email": "hank.brown@example.com", "Product": "Monitor", "Quantity": 2, "Price": 300.00, "Purchase Date": "09/19/2024", "Delivery Status": True},
    {"Transaction ID": 1009, "Customer Name": "Ivy Thompson", "Email": None, "Product": "Keyboard", "Quantity": 2, "Price": 100.00, "Purchase Date": "2024/09/20", "Delivery Status": False},
    {"Transaction ID": 1010, "Customer Name": "Jack Davis", "Email": "jack@example.com", "Product": "Mouse", "Quantity": 5, "Price": 50.00, "Purchase Date": "2024-09-21", "Delivery Status": True},
    {"Transaction ID": 1011, "Customer Name": "Alice Smith", "Email": "alice@example.com", "Product": "Laptop", "Quantity": 1, "Price": 1200.00, "Purchase Date": "2024-09-15", "Delivery Status": True},  # Duplicate entry
    {"Transaction ID": 1012, "Customer Name": "Kurt Evans", "Email": "kurt.evans@example.com", "Product": "Smartwatch", "Quantity": -1, "Price": 200.00, "Purchase Date": "2024-09-22", "Delivery Status": True},  # Outlier quantity
    {"Transaction ID": 1013, "Customer Name": "Liam Adams", "Email": "liam.adams@example.com", "Product": "Headphones", "Quantity": 2, "Price": 150.00, "Purchase Date": "2024-09-23", "Delivery Status": False},
    {"Transaction ID": 1014, "Customer Name": "Mia Clark", "Email": "mia.clark@example.com", "Product": None, "Quantity": 1, "Price": 0, "Purchase Date": "2024-09-24", "Delivery Status": True},  # Price anomaly
    {"Transaction ID": 1015, "Customer Name": "Nina Turner", "Email": None, "Product": "Tablet", "Quantity": 1, "Price": 600.00, "Purchase Date": "24-09-2024", "Delivery Status": True},
    {"Transaction ID": 1016, "Customer Name": "Oscar Harris", "Email": "oscar.harris@example.com", "Product": "Laptop", "Quantity": 2, "Price": 1200.00, "Purchase Date": "2024-09-25", "Delivery Status": True},
    {"Transaction ID": 1017, "Customer Name": "Paul Young", "Email": "paulyoung", "Product": "Monitor", "Quantity": 2, "Price": 300.00, "Purchase Date": "09/25/2024", "Delivery Status": True},
    {"Transaction ID": 1018, "Customer Name": "Quinn Lopez", "Email": None, "Product": "Smartphone", "Quantity": 1, "Price": 800.00, "Purchase Date": "2024-09-26", "Delivery Status": False},
    {"Transaction ID": 1019, "Customer Name": "Rachel Scott", "Email": "rachel.scott@example.com", "Product": "Keyboard", "Quantity": 2, "Price": 100.00, "Purchase Date": "2024-09-27", "Delivery Status": True},
    {"Transaction ID": 1020, "Customer Name": "Steve King", "Email": "steve.king@example.com", "Product": "Mouse", "Quantity": None, "Price": 50.00, "Purchase Date": "2024-09-28", "Delivery Status": True},
]

# %%
import pandas as pd
from scipy import stats
playdata = pd.DataFrame(playdata)

# %%
playdata
# Out:
#     Transaction ID    Customer Name                     Email     Product  \
# 0             1001      Alice Smith         alice@example.com      Laptop
# 1             1001      Alice Smith         alice@example.com      Laptop
# 2             1001      Alice Smith         alice@example.com      Laptop
# 3             1001      Alice Smith         alice@example.com      Laptop
# 4             1002        Bob Jones                      None  Headphones
# 5             1003  Charlie Johnson       charlie#example.com  Smartphone
# 6             1004        David Lee     david.lee@example.com      Laptop
# 7             1005     Eve Martinez  eve.martinez@example.com  Smartwatch
# 8             1006     Frank Wright                      None      Tablet
# 9             1007        Grace Lee     grace.lee@example.com      Laptop
# 10            1008       Hank Brown    hank.brown@example.com     Monitor
# 11            1009     Ivy Thompson                      None    Keyboard
# 12            1010       Jack Davis          jack@example.com       Mouse
# 13            1011      Alice Smith         alice@example.com      Laptop
# 14            1012       Kurt Evans    kurt.evans@example.com  Smartwatch
# 15            1013       Liam Adams    liam.adams@example.com  Headphones
# 16            1014        Mia Clark     mia.clark@example.com        None
# 17            1015      Nina Turner                      None      Tablet
# 18            1016     Oscar Harris  oscar.harris@example.com      Laptop
# 19            1017       Paul Young                 paulyoung     Monitor
# 20            1018      Quinn Lopez                      None  Smartphone
# 21            1019     Rachel Scott  rachel.scott@example.com    Keyboard
# 22            1020       Steve King    steve.king@example.com       Mouse
#
#     Quantity     Price  Purchase Date  Delivery Status
# 0        1.0    1200.0     2024-09-15             True
# 1        1.0    1200.0     2024-09-15             True
# 2        1.0    1200.0     2024-09-15             True
# 3        1.0    1200.0     2024-09-15             True
# 4        2.0     150.0     2024-09-16             True
# 5        1.0     800.0     16/09/2024             True
# 6        1.0    1200.0     2024-09-17            False
# 7        3.0       NaN  17th Sep 2024             True
# 8        NaN     600.0     2024-09-18            False
# 9        1.0   12000.0     2024-09-19             True
# 10       2.0     300.0     09/19/2024             True
# 11       2.0     100.0     2024/09/20            False
# 12       5.0      50.0     2024-09-21             True
# 13       1.0    1200.0     2024-09-15             True
# 14      -1.0     200.0     2024-09-22             True
# 15       2.0     150.0     2024-09-23            False
# 16       1.0       0.0     2024-09-24             True
# 17       1.0     600.0     24-09-2024             True
# 18       2.0    1200.0     2024-09-25             True
# 19       2.0     300.0     09/25/2024             True
# 20       1.0     800.0     2024-09-26            False
# 21       2.0     100.0     2024-09-27             True
# 22       NaN  500000.0     2024-09-28             True

# %%
z_scores = stats.zscore(playdata['Price'])
z_scores
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan])

# %%
playdata.duplicated() #cari duplicate yg sama sebijik mcm satu row
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# dtype: bool

# %%
df1 = playdata['Price']
df1
# Out:
# 0       1200.0
# 1       1200.0
# 2       1200.0
# 3       1200.0
# 4        150.0
# 5        800.0
# 6       1200.0
# 7          NaN
# 8        600.0
# 9      12000.0
# 10       300.0
# 11       100.0
# 12        50.0
# 13      1200.0
# 14       200.0
# 15       150.0
# 16         0.0
# 17       600.0
# 18      1200.0
# 19       300.0
# 20       800.0
# 21       100.0
# 22    500000.0
# Name: Price, dtype: float64

# %% [markdown]
# # Handling missing value

# %%
dfnew = playdata.copy()
dfnew.head()
# Out:
#    Transaction ID Customer Name              Email     Product  Quantity  \
# 0            1001   Alice Smith  alice@example.com      Laptop       1.0
# 1            1001   Alice Smith  alice@example.com      Laptop       1.0
# 2            1001   Alice Smith  alice@example.com      Laptop       1.0
# 3            1001   Alice Smith  alice@example.com      Laptop       1.0
# 4            1002     Bob Jones               None  Headphones       2.0
#
#     Price Purchase Date  Delivery Status
# 0  1200.0    2024-09-15             True
# 1  1200.0    2024-09-15             True
# 2  1200.0    2024-09-15             True
# 3  1200.0    2024-09-15             True
# 4   150.0    2024-09-16             True

# %%
#dfnew['Price'][0] = 800  #Ubah value row 0
df_withoutnull = dfnew.dropna()
dfnew.dropna(inplace=True)
dfnew.isnull().sum()
# Out:
# Transaction ID     0
# Customer Name      0
# Email              0
# Product            0
# Quantity           0
# Price              0
# Purchase Date      0
# Delivery Status    0
# dtype: int64

# %%
dfnew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, 0 to 21
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction ID   15 non-null     int64
#  1   Customer Name    15 non-null     object
#  2   Email            15 non-null     object
#  3   Product          15 non-null     object
#  4   Quantity         15 non-null     float64
#  5   Price            15 non-null     float64
#  6   Purchase Date    15 non-null     object
#  7   Delivery Status  15 non-null     bool
# dtypes: bool(1), float64(2), int64(1), object(4)
# memory usage: 975.0+ bytes

# %%
# we want to check the spread of the data or outliers in the data
plt.boxplot(dfnew['Price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x267c3487a10>,
#   <matplotlib.lines.Line2D at 0x267c3487b60>],
#  'caps': [<matplotlib.lines.Line2D at 0x267c3487cb0>,
#   <matplotlib.lines.Line2D at 0x267c3487e00>],
#  'boxes': [<matplotlib.lines.Line2D at 0x267c34878c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x267c356c050>],
#  'fliers': [<matplotlib.lines.Line2D at 0x267c356c1a0>],
#  'means': []}

# %%
dfnew = playdata.copy()

# %%
dfnew.isnull().sum()
# Out:
# Transaction ID     0
# Customer Name      0
# Email              5
# Product            1
# Quantity           2
# Price              1
# Purchase Date      0
# Delivery Status    0
# dtype: int64

# %%
dfnew.dropna(subset=['Quantity','Product'], inplace=True)   # Inplace boleh guna untuk function xyah letak assign name mcm "df ="
dfnew
# Out:
#     Transaction ID    Customer Name                     Email     Product  \
# 0             1001      Alice Smith         alice@example.com      Laptop
# 1             1001      Alice Smith         alice@example.com      Laptop
# 2             1001      Alice Smith         alice@example.com      Laptop
# 3             1001      Alice Smith         alice@example.com      Laptop
# 4             1002        Bob Jones                      None  Headphones
# 5             1003  Charlie Johnson       charlie#example.com  Smartphone
# 6             1004        David Lee     david.lee@example.com      Laptop
# 7             1005     Eve Martinez  eve.martinez@example.com  Smartwatch
# 9             1007        Grace Lee     grace.lee@example.com      Laptop
# 10            1008       Hank Brown    hank.brown@example.com     Monitor
# 11            1009     Ivy Thompson                      None    Keyboard
# 12            1010       Jack Davis          jack@example.com       Mouse
# 13            1011      Alice Smith         alice@example.com      Laptop
# 14            1012       Kurt Evans    kurt.evans@example.com  Smartwatch
# 15            1013       Liam Adams    liam.adams@example.com  Headphones
# 17            1015      Nina Turner                      None      Tablet
# 18            1016     Oscar Harris  oscar.harris@example.com      Laptop
# 19            1017       Paul Young                 paulyoung     Monitor
# 20            1018      Quinn Lopez                      None  Smartphone
# 21            1019     Rachel Scott  rachel.scott@example.com    Keyboard
#
#     Quantity    Price  Purchase Date  Delivery Status
# 0        1.0   1200.0     2024-09-15             True
# 1        1.0   1200.0     2024-09-15             True
# 2        1.0   1200.0     2024-09-15             True
# 3        1.0   1200.0     2024-09-15             True
# 4        2.0    150.0     2024-09-16             True
# 5        1.0    800.0     16/09/2024             True
# 6        1.0   1200.0     2024-09-17            False
# 7        3.0      NaN  17th Sep 2024             True
# 9        1.0  12000.0     2024-09-19             True
# 10       2.0    300.0     09/19/2024             True
# 11       2.0    100.0     2024/09/20            False
# 12       5.0     50.0     2024-09-21             True
# 13       1.0   1200.0     2024-09-15             True
# 14      -1.0    200.0     2024-09-22             True
# 15       2.0    150.0     2024-09-23            False
# 17       1.0    600.0     24-09-2024             True
# 18       2.0   1200.0     2024-09-25             True
# 19       2.0    300.0     09/25/2024             True
# 20       1.0    800.0     2024-09-26            False
# 21       2.0    100.0     2024-09-27             True

# %% [markdown]
# # Filling the value
#
# - Dont' have  outliers , missing value & duplicates

# %%
newdf = df.copy()
newdf['Price'].fillna(0, inplace=True) # Fill value kepada NAN 
newdf
# Out:
#     Transaction ID    Customer Name                     Email     Product  \
# 0             1001      Alice Smith         alice@example.com      Laptop
# 1             1002        Bob Jones                      None  Headphones
# 2             1003  Charlie Johnson       charlie#example.com  Smartphone
# 3             1004        David Lee     david.lee@example.com      Laptop
# 4             1005     Eve Martinez  eve.martinez@example.com  Smartwatch
# 5             1006     Frank Wright                      None      Tablet
# 6             1007        Grace Lee     grace.lee@example.com      Laptop
# 7             1008       Hank Brown    hank.brown@example.com     Monitor
# 8             1009     Ivy Thompson                      None    Keyboard
# 9             1010       Jack Davis          jack@example.com       Mouse
# 10            1011      Alice Smith         alice@example.com      Laptop
# 11            1012       Kurt Evans    kurt.evans@example.com  Smartwatch
# 12            1013       Liam Adams    liam.adams@example.com  Headphones
# 13            1014        Mia Clark     mia.clark@example.com        None
# 14            1015      Nina Turner                      None      Tablet
# 15            1016     Oscar Harris  oscar.harris@example.com      Laptop
# 16            1017       Paul Young                 paulyoung     Monitor
# 17            1018      Quinn Lopez                      None  Smartphone
# 18            1019     Rachel Scott  rachel.scott@example.com    Keyboard
# 19            1020       Steve King    steve.king@example.com       Mouse
#
#     Quantity   Price  Purchase Date  Delivery Status
# 0        1.0  1200.0     2024-09-15             True
# 1        2.0   150.0     2024-09-16             True
# 2        1.0   800.0     16/09/2024             True
# 3        1.0  1200.0     2024-09-17            False
# 4        3.0     0.0  17th Sep 2024             True
# 5        NaN   600.0     2024-09-18            False
# 6        1.0  1200.0     2024-09-19             True
# 7        2.0   300.0     09/19/2024             True
# 8        2.0   100.0     2024/09/20            False
# 9        5.0    50.0     2024-09-21             True
# 10       1.0  1200.0     2024-09-15             True
# 11      -1.0   200.0     2024-09-22             True
# 12       2.0   150.0     2024-09-23            False
# 13       1.0     0.0     2024-09-24             True
# 14       1.0   600.0     24-09-2024             True
# 15       2.0  1200.0     2024-09-25             True
# 16       2.0   300.0     09/25/2024             True
# 17       1.0   800.0     2024-09-26            False
# 18       2.0   100.0     2024-09-27             True
# 19       NaN    50.0     2024-09-28             True

# %%
mean_price = newdf['Price'].mean()
print(mean_price)
# Out:
# 510.0

# %% [markdown]
# - outliers in the data, we can also use median to fill up NAN data 🚎
# - mean is really affected to the outliers 🦽

# %%
newdf = df.copy()
mean_price = newdf['Price'].mean().round(2)
print(mean_price)
newdf['Price'].fillna(mean_price,inplace=True)
newdf
# Out:
# 536.84
#     Transaction ID    Customer Name                     Email     Product  \
# 0             1001      Alice Smith         alice@example.com      Laptop
# 1             1002        Bob Jones                      None  Headphones
# 2             1003  Charlie Johnson       charlie#example.com  Smartphone
# 3             1004        David Lee     david.lee@example.com      Laptop
# 4             1005     Eve Martinez  eve.martinez@example.com  Smartwatch
# 5             1006     Frank Wright                      None      Tablet
# 6             1007        Grace Lee     grace.lee@example.com      Laptop
# 7             1008       Hank Brown    hank.brown@example.com     Monitor
# 8             1009     Ivy Thompson                      None    Keyboard
# 9             1010       Jack Davis          jack@example.com       Mouse
# 10            1011      Alice Smith         alice@example.com      Laptop
# 11            1012       Kurt Evans    kurt.evans@example.com  Smartwatch
# 12            1013       Liam Adams    liam.adams@example.com  Headphones
# 13            1014        Mia Clark     mia.clark@example.com        None
# 14            1015      Nina Turner                      None      Tablet
# 15            1016     Oscar Harris  oscar.harris@example.com      Laptop
# 16            1017       Paul Young                 paulyoung     Monitor
# 17            1018      Quinn Lopez                      None  Smartphone
# 18            1019     Rachel Scott  rachel.scott@example.com    Keyboard
# 19            1020       Steve King    steve.king@example.com       Mouse
#
#     Quantity    Price  Purchase Date  Delivery Status
# 0        1.0  1200.00     2024-09-15             True
# 1        2.0   150.00     2024-09-16             True
# 2        1.0   800.00     16/09/2024             True
# 3        1.0  1200.00     2024-09-17            False
# 4        3.0   536.84  17th Sep 2024             True
# 5        NaN   600.00     2024-09-18            False
# 6        1.0  1200.00     2024-09-19             True
# 7        2.0   300.00     09/19/2024             True
# 8        2.0   100.00     2024/09/20            False
# 9        5.0    50.00     2024-09-21             True
# 10       1.0  1200.00     2024-09-15             True
# 11      -1.0   200.00     2024-09-22             True
# 12       2.0   150.00     2024-09-23            False
# 13       1.0     0.00     2024-09-24             True
# 14       1.0   600.00     24-09-2024             True
# 15       2.0  1200.00     2024-09-25             True
# 16       2.0   300.00     09/25/2024             True
# 17       1.0   800.00     2024-09-26            False
# 18       2.0   100.00     2024-09-27             True
# 19       NaN    50.00     2024-09-28             True

# %%
squared = newdf['Quantity'] ** 2
newquantity = squared / (squared**0.5)
newquantity

newdf['Quantity'] = newquantity
newdf
# Out:
#     Transaction ID    Customer Name                     Email     Product  \
# 0             1001      Alice Smith         alice@example.com      Laptop
# 1             1002        Bob Jones                      None  Headphones
# 2             1003  Charlie Johnson       charlie#example.com  Smartphone
# 3             1004        David Lee     david.lee@example.com      Laptop
# 4             1005     Eve Martinez  eve.martinez@example.com  Smartwatch
# 5             1006     Frank Wright                      None      Tablet
# 6             1007        Grace Lee     grace.lee@example.com      Laptop
# 7             1008       Hank Brown    hank.brown@example.com     Monitor
# 8             1009     Ivy Thompson                      None    Keyboard
# 9             1010       Jack Davis          jack@example.com       Mouse
# 10            1011      Alice Smith         alice@example.com      Laptop
# 11            1012       Kurt Evans    kurt.evans@example.com  Smartwatch
# 12            1013       Liam Adams    liam.adams@example.com  Headphones
# 13            1014        Mia Clark     mia.clark@example.com        None
# 14            1015      Nina Turner                      None      Tablet
# 15            1016     Oscar Harris  oscar.harris@example.com      Laptop
# 16            1017       Paul Young                 paulyoung     Monitor
# 17            1018      Quinn Lopez                      None  Smartphone
# 18            1019     Rachel Scott  rachel.scott@example.com    Keyboard
# 19            1020       Steve King    steve.king@example.com       Mouse
#
#     Quantity    Price  Purchase Date  Delivery Status
# 0        1.0  1200.00     2024-09-15             True
# 1        2.0   150.00     2024-09-16             True
# 2        1.0   800.00     16/09/2024             True
# 3        1.0  1200.00     2024-09-17            False
# 4        3.0   536.84  17th Sep 2024             True
# 5        NaN   600.00     2024-09-18            False
# 6        1.0  1200.00     2024-09-19             True
# 7        2.0   300.00     09/19/2024             True
# 8        2.0   100.00     2024/09/20            False
# 9        5.0    50.00     2024-09-21             True
# 10       1.0  1200.00     2024-09-15             True
# 11       1.0   200.00     2024-09-22             True
# 12       2.0   150.00     2024-09-23            False
# 13       1.0     0.00     2024-09-24             True
# 14       1.0   600.00     24-09-2024             True
# 15       2.0  1200.00     2024-09-25             True
# 16       2.0   300.00     09/25/2024             True
# 17       1.0   800.00     2024-09-26            False
# 18       2.0   100.00     2024-09-27             True
# 19       NaN    50.00     2024-09-28             True

# %% [markdown]
# # Z Score

# %%
newdf = playdata.copy()
newdf = pd.DataFrame(playdata)
newdf
# Out:
#     Transaction ID    Customer Name                     Email     Product  \
# 0             1001      Alice Smith         alice@example.com      Laptop
# 1             1001      Alice Smith         alice@example.com      Laptop
# 2             1001      Alice Smith         alice@example.com      Laptop
# 3             1001      Alice Smith         alice@example.com      Laptop
# 4             1002        Bob Jones                      None  Headphones
# 5             1003  Charlie Johnson       charlie#example.com  Smartphone
# 6             1004        David Lee     david.lee@example.com      Laptop
# 7             1005     Eve Martinez  eve.martinez@example.com  Smartwatch
# 8             1006     Frank Wright                      None      Tablet
# 9             1007        Grace Lee     grace.lee@example.com      Laptop
# 10            1008       Hank Brown    hank.brown@example.com     Monitor
# 11            1009     Ivy Thompson                      None    Keyboard
# 12            1010       Jack Davis          jack@example.com       Mouse
# 13            1011      Alice Smith         alice@example.com      Laptop
# 14            1012       Kurt Evans    kurt.evans@example.com  Smartwatch
# 15            1013       Liam Adams    liam.adams@example.com  Headphones
# 16            1014        Mia Clark     mia.clark@example.com        None
# 17            1015      Nina Turner                      None      Tablet
# 18            1016     Oscar Harris  oscar.harris@example.com      Laptop
# 19            1017       Paul Young                 paulyoung     Monitor
# 20            1018      Quinn Lopez                      None  Smartphone
# 21            1019     Rachel Scott  rachel.scott@example.com    Keyboard
# 22            1020       Steve King    steve.king@example.com       Mouse
#
#     Quantity    Price  Purchase Date  Delivery Status
# 0        1.0   1200.0     2024-09-15             True
# 1        1.0   1200.0     2024-09-15             True
# 2        1.0   1200.0     2024-09-15             True
# 3        1.0   1200.0     2024-09-15             True
# 4        2.0    150.0     2024-09-16             True
# 5        1.0    800.0     16/09/2024             True
# 6        1.0   1200.0     2024-09-17            False
# 7        3.0    800.0  17th Sep 2024             True
# 8        NaN    600.0     2024-09-18            False
# 9        1.0  12000.0     2024-09-19             True
# 10       2.0    300.0     09/19/2024             True
# 11       2.0    100.0     2024/09/20            False
# 12       5.0     50.0     2024-09-21             True
# 13       1.0   1200.0     2024-09-15             True
# 14      -1.0    200.0     2024-09-22             True
# 15       2.0    150.0     2024-09-23            False
# 16       1.0      0.0     2024-09-24             True
# 17       1.0    600.0     24-09-2024             True
# 18       2.0   1200.0     2024-09-25             True
# 19       2.0    300.0     09/25/2024             True
# 20       1.0    800.0     2024-09-26            False
# 21       2.0    100.0     2024-09-27             True
# 22       NaN     50.0     2024-09-28             True

# %%
z_scores = stats.zscore(newdf['Price'])
z_scores
# Out:
# array([ 0.04039541,  0.04039541,  0.04039541,  0.04039541, -0.40303599,
#        -0.12853084,  0.04039541, -0.12853084, -0.21299396,  4.60140403,
#        -0.33968865, -0.42415177, -0.44526755,  0.04039541, -0.38192021,
#        -0.40303599, -0.46638333, -0.21299396,  0.04039541, -0.33968865,
#        -0.12853084, -0.42415177, -0.44526755])

# %%
threshold = 3
# -3 < z <3
new_x = newdf[ (-threshold < z_scores) & (z_scores < threshold) ]
new_x
# Out:
#     Transaction ID    Customer Name                     Email     Product  \
# 0             1001      Alice Smith         alice@example.com      Laptop
# 1             1001      Alice Smith         alice@example.com      Laptop
# 2             1001      Alice Smith         alice@example.com      Laptop
# 3             1001      Alice Smith         alice@example.com      Laptop
# 4             1002        Bob Jones                      None  Headphones
# 5             1003  Charlie Johnson       charlie#example.com  Smartphone
# 6             1004        David Lee     david.lee@example.com      Laptop
# 7             1005     Eve Martinez  eve.martinez@example.com  Smartwatch
# 8             1006     Frank Wright                      None      Tablet
# 10            1008       Hank Brown    hank.brown@example.com     Monitor
# 11            1009     Ivy Thompson                      None    Keyboard
# 12            1010       Jack Davis          jack@example.com       Mouse
# 13            1011      Alice Smith         alice@example.com      Laptop
# 14            1012       Kurt Evans    kurt.evans@example.com  Smartwatch
# 15            1013       Liam Adams    liam.adams@example.com  Headphones
# 16            1014        Mia Clark     mia.clark@example.com        None
# 17            1015      Nina Turner                      None      Tablet
# 18            1016     Oscar Harris  oscar.harris@example.com      Laptop
# 19            1017       Paul Young                 paulyoung     Monitor
# 20            1018      Quinn Lopez                      None  Smartphone
# 21            1019     Rachel Scott  rachel.scott@example.com    Keyboard
# 22            1020       Steve King    steve.king@example.com       Mouse
#
#     Quantity   Price  Purchase Date  Delivery Status
# 0        1.0  1200.0     2024-09-15             True
# 1        1.0  1200.0     2024-09-15             True
# 2        1.0  1200.0     2024-09-15             True
# 3        1.0  1200.0     2024-09-15             True
# 4        2.0   150.0     2024-09-16             True
# 5        1.0   800.0     16/09/2024             True
# 6        1.0  1200.0     2024-09-17            False
# 7        3.0   800.0  17th Sep 2024             True
# 8        NaN   600.0     2024-09-18            False
# 10       2.0   300.0     09/19/2024             True
# 11       2.0   100.0     2024/09/20            False
# 12       5.0    50.0     2024-09-21             True
# 13       1.0  1200.0     2024-09-15             True
# 14      -1.0   200.0     2024-09-22             True
# 15       2.0   150.0     2024-09-23            False
# 16       1.0     0.0     2024-09-24             True
# 17       1.0   600.0     24-09-2024             True
# 18       2.0  1200.0     2024-09-25             True
# 19       2.0   300.0     09/25/2024             True
# 20       1.0   800.0     2024-09-26            False
# 21       2.0   100.0     2024-09-27             True
# 22       NaN    50.0     2024-09-28             True

# %%
sns.boxplot(new_x['Price'])
# Out:
# <Axes: ylabel='Price'>

# %%
mean_price = newdf['Quantity'].mean().round(2)
print(mean_price)
newdf['Quantity'].fillna(mean_price,inplace=True)
newdf

median_qnty = newdf['Quantity'].median()

newdf['Quantity'].fillna(median_qnty,inplace=True)
newdf
# Out:
# 1.72
#     Transaction ID    Customer Name                     Email     Product  \
# 0             1001      Alice Smith         alice@example.com      Laptop
# 1             1002        Bob Jones                      None  Headphones
# 2             1003  Charlie Johnson       charlie#example.com  Smartphone
# 3             1004        David Lee     david.lee@example.com      Laptop
# 4             1005     Eve Martinez  eve.martinez@example.com  Smartwatch
# 5             1006     Frank Wright                      None      Tablet
# 6             1007        Grace Lee     grace.lee@example.com      Laptop
# 7             1008       Hank Brown    hank.brown@example.com     Monitor
# 8             1009     Ivy Thompson                      None    Keyboard
# 9             1010       Jack Davis          jack@example.com       Mouse
# 10            1011      Alice Smith         alice@example.com      Laptop
# 11            1012       Kurt Evans    kurt.evans@example.com  Smartwatch
# 12            1013       Liam Adams    liam.adams@example.com  Headphones
# 13            1014        Mia Clark     mia.clark@example.com        None
# 14            1015      Nina Turner                      None      Tablet
# 15            1016     Oscar Harris  oscar.harris@example.com      Laptop
# 16            1017       Paul Young                 paulyoung     Monitor
# 17            1018      Quinn Lopez                      None  Smartphone
# 18            1019     Rachel Scott  rachel.scott@example.com    Keyboard
# 19            1020       Steve King    steve.king@example.com       Mouse
#
#     Quantity    Price  Purchase Date  Delivery Status
# 0       1.00  1200.00     2024-09-15             True
# 1       2.00   150.00     2024-09-16             True
# 2       1.00   800.00     16/09/2024             True
# 3       1.00  1200.00     2024-09-17            False
# 4       3.00   536.84  17th Sep 2024             True
# 5       1.72   600.00     2024-09-18            False
# 6       1.00  1200.00     2024-09-19             True
# 7       2.00   300.00     09/19/2024             True
# 8       2.00   100.00     2024/09/20            False
# 9       5.00    50.00     2024-09-21             True
# 10      1.00  1200.00     2024-09-15             True
# 11      1.00   200.00     2024-09-22             True
# 12      2.00   150.00     2024-09-23            False
# 13      1.00     0.00     2024-09-24             True
# 14      1.00   600.00     24-09-2024             True
# 15      2.00  1200.00     2024-09-25             True
# 16      2.00   300.00     09/25/2024             True
# 17      1.00   800.00     2024-09-26            False
# 18      2.00   100.00     2024-09-27             True
# 19      1.72    50.00     2024-09-28             True

# %%
newdf['Price'].quantile(0)
# Out:
# np.float64(0.0)

# %%
Q1 = newdf['Price'].quantile(0.25)
Q3 = newdf['Price'].quantile(0.75)

IQR_prices = Q3 - Q1
IQR_prices

# Inter quartile range
# Out:
# np.float64(762.5)

# %%
newdf
# Out:
#     Transaction ID    Customer Name                     Email     Product  \
# 0             1001      Alice Smith         alice@example.com      Laptop
# 1             1001      Alice Smith         alice@example.com      Laptop
# 2             1001      Alice Smith         alice@example.com      Laptop
# 3             1001      Alice Smith         alice@example.com      Laptop
# 4             1002        Bob Jones                      None  Headphones
# 5             1003  Charlie Johnson       charlie#example.com  Smartphone
# 6             1004        David Lee     david.lee@example.com      Laptop
# 7             1005     Eve Martinez  eve.martinez@example.com  Smartwatch
# 8             1006     Frank Wright                      None      Tablet
# 9             1007        Grace Lee     grace.lee@example.com      Laptop
# 10            1008       Hank Brown    hank.brown@example.com     Monitor
# 11            1009     Ivy Thompson                      None    Keyboard
# 12            1010       Jack Davis          jack@example.com       Mouse
# 13            1011      Alice Smith         alice@example.com      Laptop
# 14            1012       Kurt Evans    kurt.evans@example.com  Smartwatch
# 15            1013       Liam Adams    liam.adams@example.com  Headphones
# 16            1014        Mia Clark     mia.clark@example.com        None
# 17            1015      Nina Turner                      None      Tablet
# 18            1016     Oscar Harris  oscar.harris@example.com      Laptop
# 19            1017       Paul Young                 paulyoung     Monitor
# 20            1018      Quinn Lopez                      None  Smartphone
# 21            1019     Rachel Scott  rachel.scott@example.com    Keyboard
# 22            1020       Steve King    steve.king@example.com       Mouse
#
#     Quantity    Price  Purchase Date  Delivery Status
# 0        1.0   1200.0     2024-09-15             True
# 1        1.0   1200.0     2024-09-15             True
# 2        1.0   1200.0     2024-09-15             True
# 3        1.0   1200.0     2024-09-15             True
# 4        2.0    150.0     2024-09-16             True
# 5        1.0    800.0     16/09/2024             True
# 6        1.0   1200.0     2024-09-17            False
# 7        3.0    800.0  17th Sep 2024             True
# 8        NaN    600.0     2024-09-18            False
# 9        1.0  12000.0     2024-09-19             True
# 10       2.0    300.0     09/19/2024             True
# 11       2.0    100.0     2024/09/20            False
# 12       5.0     50.0     2024-09-21             True
# 13       1.0   1200.0     2024-09-15             True
# 14      -1.0    200.0     2024-09-22             True
# 15       2.0    150.0     2024-09-23            False
# 16       1.0      0.0     2024-09-24             True
# 17       1.0    600.0     24-09-2024             True
# 18       2.0   1200.0     2024-09-25             True
# 19       2.0    300.0     09/25/2024             True
# 20       1.0    800.0     2024-09-26            False
# 21       2.0    100.0     2024-09-27             True
# 22       NaN     50.0     2024-09-28             True

# %%
upper = newdf['Price'].quantile(0.95)
lower = newdf['Price'].quantile(0.05)

threshold = 3
new_df_without_outliers = newdf[ (-threshold < z_scores) & (z_scores < threshold) ]
winsorize = newdf[(newdf["Price"] > lower) & (newdf['Price'] < upper)]

# %%
plt.boxplot(winsorize['Price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x267c6271be0>,
#   <matplotlib.lines.Line2D at 0x267c6271d30>],
#  'caps': [<matplotlib.lines.Line2D at 0x267c6271e80>,
#   <matplotlib.lines.Line2D at 0x267c6271fd0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x267c6271a90>],
#  'medians': [<matplotlib.lines.Line2D at 0x267c6272120>],
#  'fliers': [<matplotlib.lines.Line2D at 0x267c6272270>],
#  'means': []}

# %% [markdown]
# # Create something binomial or normal distribution 🚂

# %%
normalarray = np.random.normal(loc=1000, size=1000)

binomialarray = np.random.binomial(n=7,p=0.5,size=1000)

plt.hist(binomialarray,bins=20,color="red")
# Out:
# (array([  8.,   0.,  56.,   0.,   0., 182.,   0.,   0., 262.,   0.,   0.,
#         266.,   0.,   0., 164.,   0.,   0.,  55.,   0.,   7.]),
#  array([0.  , 0.35, 0.7 , 1.05, 1.4 , 1.75, 2.1 , 2.45, 2.8 , 3.15, 3.5 ,
#         3.85, 4.2 , 4.55, 4.9 , 5.25, 5.6 , 5.95, 6.3 , 6.65, 7.  ]),
#  <BarContainer object of 20 artists>)

# %%
samples = np.random.normal(loc=1000,size=1000)
samples

plt.hist(samples)

#This method we will get normal distribution even the value of Y is changed
# Out:
# (array([  7.,  34., 109., 184., 254., 203., 128.,  60.,  17.,   4.]),
#  array([ 997.00900563,  997.64669651,  998.28438738,  998.92207826,
#          999.55976913, 1000.19746001, 1000.83515088, 1001.47284176,
#         1002.11053263, 1002.74822351, 1003.38591438]),
#  <BarContainer object of 10 artists>)

# %%
learners = {
        'names' : ['idrees','ibrahim','hazira','aisyah','amin']
    }
dflearners = pd.DataFrame(learners)

# %%
dflearners['state'] = ['Johor','KL','Selangor','Perak','Penang']
dflearners['state1'] = {0:1,1:3,2:4,3:5,4:90}

# %%
dflearners
# Out:
#      names     state  state1
# 0   idrees     Johor       1
# 1  ibrahim        KL       3
# 2   hazira  Selangor       4
# 3   aisyah     Perak       5
# 4     amin    Penang      90

# %%
data2 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve"],
    "Age": [25, 30, 35, 200, 40],  # 200 is an outlier
}
 
df2 = pd.DataFrame(data2)
df2
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David  200
# 4      Eve   40

# %%
sns.boxplot(df2['Age'])
# Out:
# <Axes: ylabel='Age'>
