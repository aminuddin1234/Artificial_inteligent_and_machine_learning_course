# %% [markdown]
# **Python introduction**

# %%
print('Welcome to Python')
# Out:
# Welcome to Python

# %%
print('First Example in Python')
# Out:
# First Example in Python

# %%
#input example
username=input('Enter username:')
print('Welcome Mr. \\Ms.:' + username)
# Out:
# Enter username:Amin
# Welcome Mr. \Ms.:Amin

# %%
num1=12
num2=13
result=num1+num2
print (result)
# Out:
# 25

# %%
#Fucntion of F
print(f'First Number {num1} and Second Number {num2} Result: {result}')
# Out:
# First Number 12 and Second Number 13 Result: 25

# %%
print('First Number {num1} and Second Number {num2} Result {result}')
# Out:
# First Number {num1} and Second Number {num2} Result {result}

# %%
#Funtion of 'int' untuk tambah kedua2 number, '\t' untuk tab selang yg banyak
fnum=int(input('Enter First Number'))
snum=int(input('Enter Second Number'))
result=fnum+snum
print(f'Result after adding {fnum} and {snum} is = \t {result}')
# Out:
# Enter First Number20
# Enter Second Number30
# Result after adding 20 and 30 is = 	 50

# %%
first_name='Muhammad'
last_name='Aminuddin'
full_name=first_name+' '+last_name
print(full_name)
# Out:
# Muhammad Aminuddin

# %%
type(full_name)
# Out:
# str

# %%
num=12
print(num)
type(num)
print(f'Type of fnum {type(fnum)} and snum {type(snum)}')
# Out:
# 12
# Type of fnum <class 'float'> and snum <class 'float'>

# %%
#Funtion 'float' untuk decimal, '\t' untuk tab selang yg banyak
fnum=float(input('Enter First Number: \t'))
snum=float(input('Enter Second Number: \t'))
result=fnum+snum
print(f'Result after adding {fnum} and {snum} is = \t {result}')
# Out:
# Enter First Number: 	13.34
# Enter Second Number: 	11.12
# Result after adding 13.34 and 11.12 is = 	 24.46

# %%
#boolean or bool
is_active=True
type(is_active)
# Out:
# bool

# %%
is_active=False
type(is_active)
# Out:
# bool

# %%
print('Is Active User?',is_active)
# Out:
# Is Active User? False

# %%
print(f'Is active User? {is_active}')
# Out:
# Is active User? False

# %%
# complex type
complex_num=2+3j
print(complex_num)
type(complex_num)
# Out:
# (2+3j)
# complex

# %%
#Sqeuence Type
#list []
list_ex=[1,2,3,4,5]
print(list_ex)
type(list_ex)
# Out:
# [1, 2, 3, 4, 5]
# list

# %%
cars=['Toyota', 'Hyundai', 'BMW', 'Tesla', 'Audi']
print(cars)
type(cars)
# Out:
# ['Toyota', 'Hyundai', 'BMW', 'Tesla', 'Audi']
# list

# %%
# Tuple ()
tuple_ex=(10, 30, 50, 70, 90)
print(tuple_ex)
type(tuple_ex)
# Out:
# (10, 30, 50, 70, 90)
# tuple

# %%
#set {}
set_ex={10, 20, 30, 40, 50}
print(set_ex)
type(set_ex)
# Out:
# {50, 20, 40, 10, 30}
# set

# %%
# range
range_ex=range(10)
print(range_ex)
type(range_ex)
# Out:
# range(0, 10)
# range

# %%
range_ex2=range(5)
print(range_ex2)
type(range_ex2)
# Out:
# range(0, 5)
# range

# %%
#Dictionary
emp={
    "id":1,
    "name":"Aminuddin",
    "salary":15000.56
}
print(emp)
type(emp)
# Out:
# {'id': 1, 'name': 'Aminuddin', 'salary': 15000.56}
# dict
