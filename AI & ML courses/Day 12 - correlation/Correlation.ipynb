# %% [markdown]
# * Import dataset of your choice
# * create bar plot. make it pretty
# * create a scatterplot
# * create a pairplot

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
companies = pd.read_csv('Modified_Unicorn_Companies.csv')
companies.shape
# Out:
# (1074, 10)

# %%
#companies.sort_values(by=['Year Founded'], ascending=False).head(10)
companies.drop_duplicates().shape
# Out:
# (1074, 10)

# %%
dd = companies['Country/Region'].value_counts()
dd1 = dd > 10
dd1
# Out:
# Country/Region
# United States            True
# China                    True
# India                    True
# United Kingdom           True
# Germany                  True
# France                   True
# Israel                   True
# Canada                   True
# Brazil                   True
# Singapore                True
# South Korea              True
# Australia               False
# Sweden                  False
# Hong Kong               False
# Indonesia               False
# Netherlands             False
# Mexico                  False
# Switzerland             False
# Ireland                 False
# Japan                   False
# Norway                  False
# Finland                 False
# Turkey                  False
# Spain                   False
# Belgium                 False
# United Arab Emirates    False
# Estonia                 False
# Chile                   False
# Vietnam                 False
# Denmark                 False
# ...

# %%
sns.scatterplot(data=companies,x='Year Founded',y='Continent')
plt.xticks(rotation=45, horizontalalignment='right')
# Out:
# (array([1900., 1920., 1940., 1960., 1980., 2000., 2020., 2040.]),
#  [Text(1900.0, 0, '1900'),
#   Text(1920.0, 0, '1920'),
#   Text(1940.0, 0, '1940'),
#   Text(1960.0, 0, '1960'),
#   Text(1980.0, 0, '1980'),
#   Text(2000.0, 0, '2000'),
#   Text(2020.0, 0, '2020'),
#   Text(2040.0, 0, '2040')])

# %%
china_companies = companies[(companies['Country/Region'] == 'China' ) & (companies['Year Founded'] > 2000) & (companies['Industry'] == 'Artificial intelligence')]
china_companies
# Out:
#                        Company  Valuation Date Joined  \
# 0                    Bytedance        180  2017-04-07
# 131       CloudWalk Technology          5  2018-10-08
# 175           Horizon Robotics          4  2019-02-27
# 228                     MEGVII          4  2017-10-31
# 366                 Hesai Tech          2  2020-08-01
# 515            YITU Technology          2  2018-03-08
# 539                  4Paradigm          2  2018-12-19
# 548  Black Sesame Technologies          2  2021-09-22
# 600                     XtalPi          2  2021-08-11
# 609        DeepBlue Technology          1  2018-04-16
# 728                   Unisound          1  2018-07-19
# 794      Mininglamp Technology          1  2019-03-27
# 855                      Aibee          1  2021-04-13
# 937                   iCarbonX          1  2016-04-12
# 942              Intellifusion          1  2019-03-22
# 971                    Momenta          1  2018-10-17
#
# ...

# %%
 #specify properties of our bar chart
#plt.title('Chart of student grades')
#plt.xlabel('student names')
#plt.ylabel('marks')

# %%
plt.bar(china_companies['City'],china_companies['Funding'], color = 'green')
# Out:
# <BarContainer object of 16 artists>

# %%
sns.barplot(data=china_companies,x='City',y='Funding')
plt.xticks(rotation=45, horizontalalignment='right')

print(china_companies.min())
# Out:
# Company                                                     4Paradigm
# Valuation                                                           1
# Date Joined                                                2016-04-12
# Industry                                      Artificial intelligence
# City                                                          Beijing
# Country/Region                                                  China
# Continent                                                        Asia
# Year Founded                                                     2011
# Funding                                                         $115M
# Select Investors    Ant Financial Services Group, Russia-China Inv...
# dtype: object

# %%
sns.scatterplot(data=china_companies,x='Year Founded',y='Funding',hue='City')
plt.xticks(rotation=45, horizontalalignment='right')
# Out:
# (array([2010., 2011., 2012., 2013., 2014., 2015., 2016., 2017., 2018.]),
#  [Text(2010.0, 0, '2010'),
#   Text(2011.0, 0, '2011'),
#   Text(2012.0, 0, '2012'),
#   Text(2013.0, 0, '2013'),
#   Text(2014.0, 0, '2014'),
#   Text(2015.0, 0, '2015'),
#   Text(2016.0, 0, '2016'),
#   Text(2017.0, 0, '2017'),
#   Text(2018.0, 0, '2018')])

# %%
sns.pairplot(data=china_companies,hue='Funding')

# %%
penguin = sns.load_dataset('penguins')
penguin
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.describe().round(2)
# Out:
#        total_bill     tip    size
# count      244.00  244.00  244.00
# mean        19.79    3.00    2.57
# std          8.90    1.38    0.95
# min          3.07    1.00    1.00
# 25%         13.35    2.00    2.00
# 50%         17.80    2.90    2.00
# 75%         24.13    3.56    3.00
# max         50.81   10.00    6.00

# %%
sns.barplot(data=df,x='day',y='tip')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
plt.bar(df['day'],df['total_bill'])
plt.ylabel = 'Total Bill'
plt.show()

# %%
plt.bar(df['day'],df['tip'])
# Out:
# <BarContainer object of 244 artists>

# %%
sns.pairplot(data=df)

# %%
sns.histplot(data=df, x= 'total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
df[['total_bill','tip','size']].cov().round(2)
# -------------------> do the same things

columns = ['total_bill','tip','size']
covariances = df[columns].cov()
covariances.round(2)
# Out:
#             total_bill   tip  size
# total_bill       79.25  8.32  5.07
# tip               8.32  1.91  0.64
# size              5.07  0.64  0.90

# %% [markdown]
# # covariances report
#
# total bill vs total bill = 79.25

# %%
correlation = df[columns].corr()
correlation.round(2)
# Out:
#             total_bill   tip  size
# total_bill        1.00  0.68  0.60
# tip               0.68  1.00  0.49
# size              0.60  0.49  1.00

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
cov = titanic[['fare','age','parch','sibsp','survived',	'pclass']].cov()
cov.round(2)
# Out:
#              fare     age  parch  sibsp  survived  pclass
# fare      2469.44   73.85   8.66   8.75      6.22  -22.83
# age         73.85  211.02  -2.34  -4.16     -0.55   -4.50
# parch        8.66   -2.34   0.65   0.37      0.03    0.01
# sibsp        8.75   -4.16   0.37   1.22     -0.02    0.08
# survived     6.22   -0.55   0.03  -0.02      0.24   -0.14
# pclass     -22.83   -4.50   0.01   0.08     -0.14    0.70

# %%
cor = titanic[['fare','age','parch','sibsp','survived',	'pclass']].corr()
cor.round(2)
# Out:
#           fare   age  parch  sibsp  survived  pclass
# fare      1.00  0.10   0.22   0.16      0.26   -0.55
# age       0.10  1.00  -0.19  -0.31     -0.08   -0.37
# parch     0.22 -0.19   1.00   0.41      0.08    0.02
# sibsp     0.16 -0.31   0.41   1.00     -0.04    0.08
# survived  0.26 -0.08   0.08  -0.04      1.00   -0.34
# pclass   -0.55 -0.37   0.02   0.08     -0.34    1.00

# %%
y = [4,6,10,12]
mean = sum(y) / len(y)
mean
# Out:
# 8.0

# %%
x = [10,20,30,40]
meanx = sum(x) / len(x)
meanx
# Out:
# 25.0

# %%
covariance = (10 - x)

# %% [markdown]
# pearson correlation coefficcent
#
# method = 'pearson' will be default is we use corr()
# - corelation heatmap

# %%
sns.heatmap(correlation, annot=True)
# Out:
# <Axes: >

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
covariance = iris[['sepal_length'	,'sepal_width'	,'petal_length',	'petal_width']].cov()
covariance
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      0.685694    -0.042434      1.274315     0.516271
# sepal_width      -0.042434     0.189979     -0.329656    -0.121639
# petal_length      1.274315    -0.329656      3.116278     1.295609
# petal_width       0.516271    -0.121639      1.295609     0.581006

# %%
correlation = iris[['sepal_length'	,'sepal_width'	,'petal_length',	'petal_width']].corr()
correlation
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(covariance,annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data=iris,x='petal_length',y='petal_width')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 sns.pairplot(data=iris,x= 'petal_length',y='petal_width')
#
# TypeError: pairplot() got an unexpected keyword argument 'x'

# %% [markdown]
# covariance
# - how to variables are changing wrt each other covariance
# - using a formula
# - pearson corelation coefficent - cov/stdx and stdy
# - heatmap - most of the times -

# %%
##create a new column:
# tip_pct = tip / total_bill * 100
#compute corelation of tip_pct with total bill and with size and observed the changes

tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
##create a new column:
# tip_pct = tip / total_bill * 100
#compute corelation of tip_pct with total bill and with size and observed the changes

tips['tip_pct'] = [(tips['tip']) / (tips['total_bill']) * 100]
tips
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[94], line 5
#       1 ##create a new column:
#       2 # tip_pct = tip / total_bill * 100
#       3 #compute corelation of tip_pct with total bill and with size and observed the changes
# ----> 5 tips['tip_pct'] = [(tips['tip']) / (tips['total_bill']) * 100]
#       6 tips
#
# File c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:4322, in DataFrame.__setitem__(self, key, value)
#    4319     self._setitem_array([key], value)
#    4320 else:
#    4321     # set column
# -> 4322     self._set_item(key, value)
#
# File c:\Users\User\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:4535, in DataFrame._set_item(self, key, value)
#    4525 def _set_item(self, key, value) -> None:
#    4526     """
#    4527     Add series to DataFrame in specified column.
# ...

# %%
tip3 = tips['tip']
tbill3 = tips['total_bill']

# %%
tip_pct = tip3 / tbill3 * 100

# %%
tips['tip_pct'] = tip_pct

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size    tip_pct
# 0         16.99  1.01  Female     No   Sun  Dinner     2   5.944673
# 1         10.34  1.66    Male     No   Sun  Dinner     3  16.054159
# 2         21.01  3.50    Male     No   Sun  Dinner     3  16.658734
# 3         23.68  3.31    Male     No   Sun  Dinner     2  13.978041
# 4         24.59  3.61  Female     No   Sun  Dinner     4  14.680765
# ..          ...   ...     ...    ...   ...     ...   ...        ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  20.392697
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2   7.358352
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2   8.822232
# 242       17.82  1.75    Male     No   Sat  Dinner     2   9.820426
# 243       18.78  3.00  Female     No  Thur  Dinner     2  15.974441
#
# [244 rows x 8 columns]

# %%
cor1 = tips[['total_bill','size','tip_pct']].corr()
cor1.round(2)
# Out:
#             total_bill  size  tip_pct
# total_bill        1.00  0.60    -0.34
# size              0.60  1.00    -0.14
# tip_pct          -0.34 -0.14     1.00

# %%
sns.heatmap(data=cor1,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# - dark = not much corelation
# - more light color = much corelation
