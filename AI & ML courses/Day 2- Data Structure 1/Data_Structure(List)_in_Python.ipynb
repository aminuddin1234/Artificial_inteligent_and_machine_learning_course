# %%
#List In Python
#Python lists are containers to store a set of values of any data type.
#List items are ordered, changeable, and allow duplicate values
#Denote the list using []

# %%
emps=['Sam','Ravi','Si','Vi','Amit',12,45, True, None, 12.45]

# %%
print(emps)
# Out:
# ['Sam', 'Ravi', 'Si', 'Vi', 'Amit', 12, 45, True, None, 12.45]

# %%
#Indexing start from 0 and goes upto -1
#Len=Number of items in list
print('Number of items in list : ',len(emps))
# Out:
# Number of items in list :  10

# %%
colors=['Red','Yellow','Green','White','Red','Blue']

# %%
print('Number of items in list : ',len(colors))
# Out:
# Number of items in list :  6

# %%
print('All Items from Emps')
for item in emps:
  print(item)
# Out:
# All Items from Emps
# Sam
# Ravi
# Si
# Vi
# Amit
# 12
# 45
# True
# None
# 12.45

# %%
print('All colors')
for color in colors:
  print(color)
# Out:
# All colors
# Red
# Yellow
# Green

# %%
print('All Items from Emps')
for x in emps:     # for (boleh letak mcm2 kat tgh tu) in (kena letak point):
  print(x)
# Out:
# All Items from Emps
# Sam
# Ravi
# Si
# Vi
# Amit
# 12
# 45
# True
# None
# 12.45

# %%
actors=['Salman Khan','Sharukh Khan','Amir Khan','Amitabh','Ranbir Kappor','Vin Diesel','Leo']

# %%
print('Number of actors in list are: ',len(actors))
for actor in actors:
  print(actor, )
# Out:
# Number of actors in list are:  7
# Salman Khan
# Sharukh Khan
# Amir Khan
# Amitabh
# Ranbir Kappor
# Vin Diesel
# Leo

# %%
print('All Colors')
for color in colors:
  print(f'{color} is color and appear : {colors.count(color)} times')
# Out:
# All Colors
# Red is color and appear : 2 times
# Yellow is color and appear : 1 times
# Green is color and appear : 1 times
# White is color and appear : 1 times
# Red is color and appear : 2 times
# Blue is color and appear : 1 times

# %%
print('All Colors')
for x in colors:
  print(f'{x} is color and appear : {colors.count(x)} times')
# Out:
# All Colors
# Red is color and appear : 2 times
# Yellow is color and appear : 1 times
# Green is color and appear : 1 times
# White is color and appear : 1 times
# Red is color and appear : 2 times
# Blue is color and appear : 1 times

# %%
#Indexing start from 0 and goes upto -1
for i in range(len(actors)):
  print(f'{i}->{actors[i]}')
# Out:
# 0->Salman Khan
# 1->Sharukh Khan
# 2->Amir Khan
# 3->Amitabh
# 4->Ranbir Kappor
# 5->Vin Diesel
# 6->Leo

# %%
print(actors[5])
# Out:
# Vin Diesel

# %%
print('Number of Actors:',len(actors))
for (i,actor) in enumerate(actors):
  print(f'{i+1}. {actor}')
# Out:
# Number of Actors: 7
# 1. Salman Khan
# 2. Sharukh Khan
# 3. Amir Khan
# 4. Amitabh
# 5. Ranbir Kappor
# 6. Vin Diesel
# 7. Leo

# %%
print('Number of Actors:',len(actors))
for i in range(len(actors)):
  print(f'{i+1}. {actors[i]}')
# Out:
# Number of Actors: 7
# 1. Salman Khan
# 2. Sharukh Khan
# 3. Amir Khan
# 4. Amitabh
# 5. Ranbir Kappor
# 6. Vin Diesel
# 7. Leo

# %% [markdown]
# Create a list of cars using following brands bmw, tesla, honda, proton, toyota, tata
# * display show the list like following
# * 1->bmw
# * 2->tesla

# %%
cars=('bmw', 'tesla', 'honda', 'proton', 'toyota', 'tata')

# %%
print('List of cars:',len(cars))
for (i,cars) in enumerate(cars):
  print(f'{i+1}->{cars}')
# Out:
# List of cars: 6
# 1->bmw
# 2->tesla
# 3->honda
# 4->proton
# 5->toyota
# 6->tata

# %%
#Last item from list
print('last actor from actors: ',actors[-1])
# Out:
# last actor from actors:  Leo

# %%
print(actors)
# Out:
# []

# %%
#List slicing
print(actors[1:4])
# Out:
# ['Sharukh Khan', 'Amir Khan', 'Amitabh']

# %%
print('First Three actors')
print(actors[:3])
# Out:
# First Three actors
# ['Salman Khan', 'Sharukh Khan', 'Amir Khan']

# %%
print('Last Three actors')
print(actors[-3:])
# Out:
# Last Three actors
# ['Ranbir Kappor', 'Vin Diesel', 'Leo']

# %%
actors.append('Leo')

# %%
actors.append('Manoj Kumar')

# %%
#pop() to remove item from end of the list

# %%
print('Add an actor at the end of list')
actors.pop()
# Out:
# Add an actor at the end of list
# 'Leo'

# %%
print(actors)
# Out:
# ['Salman Khan', 'Sharukh Khan', 'Amir Khan', 'Amitabh', 'Ranbir Kappor', 'Vin Diesel', 'Leo', 'Manoj Kumar']

# %%
print('insert actor after 3rd position')
actors.insert(3,'Rajnikanth')
# Out:
# insert actor after 3rd position

# %%
print(actors)
# Out:
# ['Salman Khan', 'Sharukh Khan', 'Amir Khan', 'Rajnikanth', 'Amitabh', 'Ranbir Kappor', 'Vin Diesel', 'Leo', 'Manoj Kumar']

# %%
#Delete all items
actors.clear()

# %%
print(actors)
# Out:
# ['Salman Khan', 'Sharukh Khan', 'Amir Khan', 'Amitabh', 'Ranbir Kappor', 'Vin Diesel', 'Leo']

# %%
actors.sort()
print("List after sorting")
print(actors)
# Out:
# List after sorting
# ['Amir Khan', 'Amitabh', 'Leo', 'Ranbir Kappor', 'Salman Khan', 'Sharukh Khan', 'Vin Diesel']

# %%
actors.reverse()
print('List after reverse: ')
print(actors)
# Out:
# List after reverse:
# ['Vin Diesel', 'Sharukh Khan', 'Salman Khan', 'Ranbir Kappor', 'Leo', 'Amitabh', 'Amir Khan']

# %%
list_numbers=[100,200,300,400,500]

# %%
print('Number of items in list: \t',len(list_numbers))
print('Maximum number in list: \t',max(list_numbers))
print('Minimum number in list: \t',min(list_numbers))
print('Sum of number in list: \t',sum(list_numbers))
# Out:
# Number of items in list: 	 5
# Maximum number in list: 	 500
# Minimum number in list: 	 100
# Sum of number in list: 	 1500

# %%
for (i,num) in enumerate(list_numbers):
  print(f'{i+1}. {num}')
# Out:
# 1. 100
# 2. 200
# 3. 300
# 4. 400
# 5. 500

# %%
# add item at the end of list
list_numbers.append(150)

# %%
print(list_numbers)
# Out:
# [100, 200, 300, 400, 500, 150]

# %%
list_numbers.insert(2,250)

# %%
print(list_numbers)
# Out:
# [100, 200, 250, 300, 400, 500, 150]

# %%
list_numbers.pop()
# Out:
# 150

# %%
list_numbers
# Out:
# [100, 200, 250, 300, 400, 500]

# %%
list_numbers.remove(300)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1572870572.py in <cell line: 0>()
# ----> 1 list_numbers.remove(300)
#
# ValueError: list.remove(x): x not in list

# %%
list_numbers
# Out:
# [100, 200, 250, 400, 500]

# %%
shopping_cart=[]

# %%
choice='y'
while(choice=='y'):
  item=input('Enter item to add in cart: ')
  shopping_cart.append(item)
  choice=(input('Do you want to add more items? (y/n): ')).lower()

print('Your shopping cart contains: ')
for item in shopping_cart:
  print(item)
# Out:
# Enter item to add in cart: jambu
# Do you want to add more items? (y/n): y
# Enter item to add in cart: pelam
# Do you want to add more items? (y/n): y
# Enter item to add in cart: durian
# Do you want to add more items? (y/n): n
# Your shopping cart contains:
# jambu
# pelam
# durian
