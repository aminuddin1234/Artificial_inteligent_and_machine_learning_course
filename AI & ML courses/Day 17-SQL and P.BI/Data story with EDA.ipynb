# %% [markdown]
# #  data storytelling
#
# - flow the *story*
#
# - always ask yourself a *questions* based on the data you have
#
# - *Data analytics*   pd.describe()
#
# - *cleaned data* - drop na , - fill na , drop duplicate
#
# - *Visualization*(Visual learners) --create figures   ... bar, line, pie, histogram, box plot, scatter plot, heat map
# - Find patterns
#
# - *Insights*
# - generate insights (you play with data/visual to answers the questions)
#
# - *Recommendation*
# - give a reason based on insights part and suggest the things.
