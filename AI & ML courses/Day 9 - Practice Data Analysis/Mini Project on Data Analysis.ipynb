# %% [markdown]
# Data visualization is a small part of the overall EDA process
#
# * Data science - Data Analysis ---->
#
# * DA
# 1. being able handle large volumes data
# 2. to be able to find data - data sources
# 3. import that data into your python files
# 4. should be able to analyse it
# * by using visualization tools we learnt
# * matplotlib and seaborn
#
# Exersice :
# 1. Find data related to the titanic ship
# * dwld it, import to nbs, make some visualization, write 4 lines about data(give some information about the data that not easily observable, make some judgement/ inferences)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
titanic = pd.read_csv('Titanic-Dataset.csv')
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
titanic.shape
# Out:
# (891, 12)

# %%
new_titanic = titanic.drop(['PassengerId','Pclass','Ticket','Fare','Cabin','Embarked'],axis=1)
print('Survived Rate = 1.Yes  0.No')
titanic1 = new_titanic.dropna()
titanic1
# Out:
# Survived Rate = 1.Yes  0.No
#      Survived                                               Name     Sex  \
# 0           0                            Braund, Mr. Owen Harris    male
# 1           1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2           1                             Heikkinen, Miss. Laina  female
# 3           1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4           0                           Allen, Mr. William Henry    male
# ..        ...                                                ...     ...
# 885         0               Rice, Mrs. William (Margaret Norton)  female
# 886         0                              Montvila, Rev. Juozas    male
# 887         1                       Graham, Miss. Margaret Edith  female
# 889         1                              Behr, Mr. Karl Howell    male
# 890         0                                Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch
# 0    22.0      1      0
# ...

# %%
sns.scatterplot(data=titanic1,x='SibSp',y='Parch',hue='Sex')
# Out:
# <Axes: xlabel='SibSp', ylabel='Parch'>

# %%
sns.barplot(data=titanic1,x='Sex',y='Age',hue='Survived')
print('female has highest survival rate than male')
# Out:
# female has highest survival rate than male

# %%
sns.scatterplot(data=titanic1,x='Age',y='Survived',hue='Sex')
# Out:
# <Axes: xlabel='Age', ylabel='Survived'>

# %% [markdown]
# **Finding the Data**
#
# * Primary sources of data
# 1. data that i collect ourselves
# 2. problem -people you meet?
# 3. sensor data
# 4. you have to invest time, effort into this
#     * need infrastructure
#     * even money as well
#     * researchers, people who have some incentive like
#
# *secondary* -Rely on this a lot
#     * data that you get from someone

# %% [markdown]
# *PROBLEM SCOPING* 🧨🧨
#
# 4ws framework:
#
# **what the problem is:**
# 1. company have issues about why workers suddenly want to quit in this month.
#
# **who is the solution is for**
# 1. for the workers and management
#
# **Where is the problem occuring**
# 1. wages
# 2. get new jobs
# 3. distance between home to work place
#
# **Why it is worth solving**
# 1. to find what the root cause of workers want to quit, and solve/fix any problem that related to the management.
#
# *DATA ACQUISITION* 🎞🎞
#
# Use secondary Data Sources:
#
# Choices -->
# 1. Kaggle
# 2. gov Sources
# 3. UCI
# 4. Github
#
# *Data* *visualization* 👓👓
#
# 1. create some visualization
# 2. seaborn/matplotlib
# 3. create insights about related to the problem

# %%
import numpy as np
import pandas as pd

# %%
a = np.random.randint(100000,1000000,1000)
b = np.random.randint(100000,1000000,1000)
c = np.random.randint(100000,1000000,1000)
d = np.random.randint(100000,1000000,1000)

# %%
population = {
    'KL' : a,
    'SG' : b,
    'PJ' : c,
    'HK' : d
   }

# %%
df = pd.DataFrame(population)
df
# Out:
#          KL      SG      PJ      HK
# 0    916447  967262  521026  238573
# 1    212722  850575  456435  208515
# 2    916479  535336  862430  271936
# 3    441520  951858  525181  467936
# 4    716213  490667  338772  350413
# ..      ...     ...     ...     ...
# 995  792105  152538  164746  585212
# 996  677553  553800  460460  632105
# 997  736228  382239  177104  932795
# 998  270343  538309  292628  882494
# 999  130538  343791  448340  569280
#
# [1000 rows x 4 columns]

# %%
employee = pd.read_csv('HR.csv')
employee
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
employee.shape
# Out:
# (14999, 10)

# %%
sns.relplot(data=employee,x='average_montly_hours',y='sales',hue='left')

# %%
sns.set_theme(style='darkgrid')

# %%
sns.barplot(data=employee,x='Work_accident',y='sales',hue='salary')
# Out:
# <Axes: xlabel='Work_accident', ylabel='sales'>

# %%
sns.relplot(data=employee,x='Work_accident',y='sales',hue='salary')

# %% [markdown]
# my dataset is about survey why employee quit based on different dept.
#
# based on this barplot chart.
# 1. management department is the longest serve to the company
# 2. mostly HR department is the shortest serve to the company
# 3. even management dept have the longest serve to the company, but they not resign
# 4. RandD and product_management have the equal serve years to the company and share the same rate for resign.
# 5. support, technical and sales have most rate left due to increase average hours spend on works.
# 6. as we can see all dept pretend not resign when low average hours spend on works
# 7. mostly resign rate increase when 125 appears as average monthly hours.
# 8. Technical, support and sales department have consistently resign rate starting above 200 average monthly hours works.

# %%
sns.relplot(data=employee,x='average_montly_hours',y='sales',hue='left')

# %%
sns.barplot(data=employee,x='time_spend_company',y='sales',hue='left')
# Out:
# <Axes: xlabel='time_spend_company', ylabel='sales'>

# %%
sns.set_theme(style='darkgrid')

# %%
sns.displot(employee,x='salary',y='time_spend_company',hue='sales')

# %% [markdown]
# **Data Handling parts**
#
# *How to change the headers table/dataframe??*
# 1. somethings might just be data, and no headers
# 2. table headers name not make sense
# 3. you need to assign a new names

# %%
#column 1    column 2    column 3
import pandas as pd
df = pd.read_csv('iris.csv')
df.head()
# Out:
#      p    1    2    r       g
# 0  5.1  3.5  1.4  0.2  setosa
# 1  4.9  3.0  1.4  0.2  setosa
# 2  4.7  3.2  1.3  0.2  setosa
# 3  4.6  3.1  1.5  0.2  setosa
# 4  5.0  3.6  1.4  0.2  setosa

# %%
df[['p','1','r']]
# Out:
#        p    1    r
# 0    5.1  3.5  0.2
# 1    4.9  3.0  0.2
# 2    4.7  3.2  0.2
# 3    4.6  3.1  0.2
# 4    5.0  3.6  0.2
# ..   ...  ...  ...
# 145  6.7  3.0  2.3
# 146  6.3  2.5  1.9
# 147  6.5  3.0  2.0
# 148  6.2  3.4  2.3
# 149  5.9  3.0  1.8
#
# [150 rows x 3 columns]

# %%
df[['p','2','g']]  #Same method
df.loc[:][['p','2','g']]
# Out:
#        p    2          g
# 0    5.1  1.4     setosa
# 1    4.9  1.4     setosa
# 2    4.7  1.3     setosa
# 3    4.6  1.5     setosa
# 4    5.0  1.4     setosa
# ..   ...  ...        ...
# 145  6.7  5.2  virginica
# 146  6.3  5.0  virginica
# 147  6.5  5.2  virginica
# 148  6.2  5.4  virginica
# 149  5.9  5.1  virginica
#
# [150 rows x 3 columns]

# %%
#df[][]   # column x rows
df.iloc[0:10][0:2]
# Out:
#      p    1    2    r       g
# 0  5.1  3.5  1.4  0.2  setosa
# 1  4.9  3.0  1.4  0.2  setosa

# %%
#This is how you target a row 
df.loc[4]  #targeting row
df['g'][4] #goes first to column, row
df.loc[0:10][['p','2','g']]
df['2']  #Directly access to columns name (column label)
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: 2, Length: 150, dtype: float64

# %%
newdf = df.drop(['p','2','g'],axis=1)
newdf
# Out:
#        1    r
# 0    3.5  0.2
# 1    3.0  0.2
# 2    3.2  0.2
# 3    3.1  0.2
# 4    3.6  0.2
# ..   ...  ...
# 145  3.0  2.3
# 146  2.5  1.9
# 147  3.0  2.0
# 148  3.4  2.3
# 149  3.0  1.8
#
# [150 rows x 2 columns]

# %%
iris = pd.read_csv('iris.csv', header =None, skiprows=1, names=['a','b','c','d','e'])
iris.head(2)                   #Header= kita bgi header table hilang    #names = bgi nama kt table
# Out:
#      a    b    c    d       e
# 0  5.1  3.5  1.4  0.2  setosa
# 1  4.9  3.0  1.4  0.2  setosa

# %%
column = ['p_len','p_wid','s_len','s_wid','species']

iris = pd.read_csv('iris.csv', header =None, skiprows=1, names=column)
iris.head(2)                   #Header= kita bgi header table hilang    #names = bgi nama kt table
# Out:
#    p_len  p_wid  s_len  s_wid species
# 0    5.1    3.5    1.4    0.2  setosa
# 1    4.9    3.0    1.4    0.2  setosa
