# %% [markdown]
# [Explanation vis](https://mlu-explain.github.io/decision-tree/)
#
# - decision tree is a series of Yes/No
#
# - if u think about decision tree, think about hierarecy/brances
#
# - node is caring of condition

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -----

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier,plot_tree


from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
titanic = sns.load_dataset('titanic')
titanic = pd.DataFrame(titanic)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
x,y = pd.factorize(titanic['survived'])
titanic['survived_code'] = x

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  survived_code
# 0      man        True  NaN  Southampton    no  False              0
# 1    woman       False    C    Cherbourg   yes  False              1
# 2    woman       False  NaN  Southampton   yes   True              1
# 3    woman       False    C  Southampton   yes  False              1
# 4      man        True  NaN  Southampton    no   True              0
# ..     ...         ...  ...          ...   ...    ...            ...
# 886    man        True  NaN  Southampton    no   True              0
# 887  woman       False    B  Southampton   yes   True              1
# 888  woman       False  NaN  Southampton    no  False              0
# 889    man        True    C    Cherbourg   yes   True              1
# 890    man        True  NaN   Queenstown    no   True              0
#
# [891 rows x 16 columns]

# %%
x = titanic[['fare']]
y = titanic['survived_code']

# %%
model_dt = DecisionTreeClassifier()
model_lr = LogisticRegression()

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, random_state= 42, test_size= 0.2)

model_dt.fit(x_train,y_train)
model_lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred_dt = model_dt.predict(x_test)
y_pred_lr = model_lr.predict(x_test)

# %%
# Very great report for model 

cr_dt = classification_report(y_test,y_pred_dt)         
cr_lr = classification_report(y_test,y_pred_lr)
print(cr_dt,cr_lr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.84      0.76       105
#            1       0.68      0.49      0.57        74
#
#     accuracy                           0.69       179
#    macro avg       0.69      0.66      0.66       179
# weighted avg       0.69      0.69      0.68       179
#                precision    recall  f1-score   support
#
#            0       0.64      0.95      0.76       105
#            1       0.77      0.23      0.35        74
#
#     accuracy                           0.65       179
#    macro avg       0.70      0.59      0.56       179
# weighted avg       0.69      0.65      0.59       179

# %%
titanic['fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 891, dtype: float64

# %%
plt.Figure(figsize=(25,16), dpi=300)
plot_tree(model_dt, 
          feature_names=['fare'], 
          class_names=['No', 'Yes'], 
          max_depth=3,
           filled=True,
            rounded=True,
             fontsize=5 )
# Out:
# [Text(0.45535714285714285, 0.9, 'fare <= 10.481\ngini = 0.469\nsamples = 712\nvalue = [444, 268]\nclass = No'),
#  Text(0.19642857142857142, 0.7, 'fare <= 7.133\ngini = 0.321\nsamples = 274\nvalue = [219, 55]\nclass = No'),
#  Text(0.32589285714285715, 0.8, 'True  '),
#  Text(0.10714285714285714, 0.5, 'fare <= 7.013\ngini = 0.114\nsamples = 33\nvalue = [31, 2]\nclass = No'),
#  Text(0.07142857142857142, 0.3, 'fare <= 6.962\ngini = 0.142\nsamples = 26\nvalue = [24, 2]\nclass = No'),
#  Text(0.03571428571428571, 0.1, '\n  (...)  \n'),
#  Text(0.10714285714285714, 0.1, '\n  (...)  \n'),
#  Text(0.14285714285714285, 0.3, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = No'),
#  Text(0.2857142857142857, 0.5, 'fare <= 7.883\ngini = 0.343\nsamples = 241\nvalue = [188, 53]\nclass = No'),
#  Text(0.21428571428571427, 0.3, 'fare <= 7.867\ngini = 0.415\nsamples = 109\nvalue = [77, 32]\nclass = No'),
#  Text(0.17857142857142858, 0.1, '\n  (...)  \n'),
#  Text(0.25, 0.1, '\n  (...)  \n'),
#  Text(0.35714285714285715, 0.3, 'fare <= 7.91\ngini = 0.268\nsamples = 132\nvalue = [111, 21]\nclass = No'),
#  Text(0.32142857142857145, 0.1, '\n  (...)  \n'),
#  Text(0.39285714285714285, 0.1, '\n  (...)  \n'),
#  Text(0.7142857142857143, 0.7, 'fare <= 52.277\ngini = 0.5\nsamples = 438\nvalue = [225.0, 213.0]\nclass = No'),
#  Text(0.5848214285714286, 0.8, '  False'),
#  Text(0.5714285714285714, 0.5, 'fare <= 39.644\ngini = 0.484\nsamples = 318\nvalue = [187, 131]\nclass = No'),
#  Text(0.5, 0.3, 'fare <= 12.825\ngini = 0.491\nsamples = 292\nvalue = [166.0, 126.0]\nclass = No'),
#  Text(0.4642857142857143, 0.1, '\n  (...)  \n'),
#  Text(0.5357142857142857, 0.1, '\n  (...)  \n'),
#  Text(0.6428571428571429, 0.3, 'fare <= 40.852\ngini = 0.311\nsamples = 26\nvalue = [21, 5]\nclass = No'),
#  Text(0.6071428571428571, 0.1, '\n  (...)  \n'),
#  Text(0.6785714285714286, 0.1, '\n  (...)  \n'),
#  Text(0.8571428571428571, 0.5, 'fare <= 79.825\ngini = 0.433\nsamples = 120\nvalue = [38, 82]\nclass = Yes'),
#  Text(0.7857142857142857, 0.3, 'fare <= 69.425\ngini = 0.479\nsamples = 58\nvalue = [23, 35]\nclass = Yes'),
#  Text(0.75, 0.1, '\n  (...)  \n'),
#  Text(0.8214285714285714, 0.1, '\n  (...)  \n'),
#  Text(0.9285714285714286, 0.3, 'fare <= 211.419\ngini = 0.367\nsamples = 62\nvalue = [15, 47]\nclass = Yes'),
#  Text(0.8928571428571429, 0.1, '\n  (...)  \n'),
#  Text(0.9642857142857143, 0.1, '\n  (...)  \n')]

# %%
plt.Figure(figsize=(25,16), dpi=300)
plot_tree(model_dt, 
          feature_names=['fare'], 
          class_names=titanic['alive'], 
          max_depth=2,
           filled=True,
            rounded=True,
             fontsize=6 )
# Out:
# [Text(0.5, 0.875, 'fare <= 10.481\ngini = 0.469\nsamples = 712\nvalue = [444, 268]\nclass = no'),
#  Text(0.25, 0.625, 'fare <= 7.133\ngini = 0.321\nsamples = 274\nvalue = [219, 55]\nclass = no'),
#  Text(0.375, 0.75, 'True  '),
#  Text(0.125, 0.375, 'fare <= 7.013\ngini = 0.114\nsamples = 33\nvalue = [31, 2]\nclass = no'),
#  Text(0.0625, 0.125, '\n  (...)  \n'),
#  Text(0.1875, 0.125, '\n  (...)  \n'),
#  Text(0.375, 0.375, 'fare <= 7.883\ngini = 0.343\nsamples = 241\nvalue = [188, 53]\nclass = no'),
#  Text(0.3125, 0.125, '\n  (...)  \n'),
#  Text(0.4375, 0.125, '\n  (...)  \n'),
#  Text(0.75, 0.625, 'fare <= 52.277\ngini = 0.5\nsamples = 438\nvalue = [225.0, 213.0]\nclass = no'),
#  Text(0.625, 0.75, '  False'),
#  Text(0.625, 0.375, 'fare <= 39.644\ngini = 0.484\nsamples = 318\nvalue = [187, 131]\nclass = no'),
#  Text(0.5625, 0.125, '\n  (...)  \n'),
#  Text(0.6875, 0.125, '\n  (...)  \n'),
#  Text(0.875, 0.375, 'fare <= 79.825\ngini = 0.433\nsamples = 120\nvalue = [38, 82]\nclass = yes'),
#  Text(0.8125, 0.125, '\n  (...)  \n'),
#  Text(0.9375, 0.125, '\n  (...)  \n')]
