# %%
# Creating CSV file for Labour Productivity per Employment - Annual Percentage Change
import os
import pandas as pd

# Ensure output directory exists
output_dir = "/mnt/data"
os.makedirs(output_dir, exist_ok=True)

# Define the data
data = [
    ["Value added per employment", "(%)", 5.8, 10.6, 4.0, 2.5, -0.20, 0.4, 0.3, 2.0, 3.10, 2.5, 2.1, 1.3],
    ["Agriculture", "(%)", -0.9, 3.2, 3.1, -0.2, -1.4, -0.5, 0.3, 1.9, 6.4, 2.6, -1.9, 0.3],
    ["Mining & Quarrying", "(%)", -3.4, 10.1, 7.0, 2.5, -3.0, -2.5, 2.9, 4.3, 2.5, -2.9, -1.1, -3.2],
    ["Manufacturing", "(%)", 4.1, 8.3, 1.6, 0.6, -2.6, -3.1, -3.2, 0.3, 3.0, 4.1, 2.8, 2.2],
    ["Vegetable and animal oils & fats and food processing", "(%)", -2.3, -0.2, 0.7, 2.2, -3.2, -2.5, 1.8, -3.7, 2.5, 5.4, 4.0, 6.3],
    ["Beverages and tobacco products", "(%)", 24.6, 48.7, -6.2, 3.3, 3.4, 0.4, 2.1, 4.8, 4.0, 7.4, 4.9, -0.1],
    ["Textiles, wearing apparel and leather products", "(%)", 0.7, 6.3, 2.8, 7.4, 8.5, 3.9, -1.3, 0.0, 2.4, 3.2, 0.6, -0.6],
    ["Wood products, furniture, paper products and printing", "(%)", 5.5, 12.3, -2.6, -4.9, -5.6, -3.9, -1.9, 1.0, 3.8, 5.8, 3.0, 1.1],
    ["Petroleum, chemical, rubber and plastic products", "(%)", -3.2, 0.7, -0.9, 0.6, -2.0, -3.0, -3.1, -0.5, 1.6, 2.0, 0.8, 1.0],
    ["Non-metallic mineral products, basic metal and fabricated metal products", "(%)", 5.7, 9.9, 0.9, 2.5, 3.9, 2.2, 2.8, 5.2, 6.3, 6.5, 2.2, 0.9],
    ["Electrical, electronic and optical products", "(%)", 10.0, 11.5, 4.9, -2.2, -5.5, -5.2, -7.3, 0.9, 3.0, 5.7, 6.5, 6.4],
    ["Transport equipment, other manufacturing and repair", "(%)", 12.8, 30.8, -2.1, 0.7, -5.2, -1.0, 1.9, 2.5, 3.9, -0.3, -3.4, -8.8],
    ["Construction", "(%)", 3.2, 14.8, 10.3, 6.6, 5.1, 5.6, 2.2, 10.7, 16.2, 18.9, 19.7, 13.2],
    ["Services", "(%)", 8.1, 11.9, 4.3, 3.1, 0.7, 1.8, 1.1, 1.9, 2.1, 1.3, 1.8, 0.8],
    ["Utilities", "(%)", 0.6, 2.7, -3.2, 0.0, 2.9, 1.8, 2.7, 3.6, -2.8, -2.7, -4.1, -5.9],
    ["Wholesale & retail trade", "(%)", 11.2, 18.1, 4.8, 6.5, 2.6, 3.6, 2.6, 1.3, 1.0, 0.4, 0.6, 0.1],
    ["Food & beverages and Accommodation", "(%)", 33.3, 46.3, 16.4, 4.1, -1.9, -2.9, -3.8, -0.5, -0.8, -1.0, 1.2, 0.2],
    ["Transportation and storage", "(%)", 26.4, 27.9, 9.5, 8.0, 6.6, 7.5, 9.8, 8.5, 5.6, 5.5, 5.7, 4.3],
    ["Information and communication", "(%)", 1.9, 0.4, 0.8, -2.2, -1.3, -1.0, 0.00, 0.5, 0.3, 0.5, 1.20, -0.1],
    ["Finance and insurance", "(%)", -1.1, 3.2, -0.5, -0.6, -7.2, -2.6, -6.8, -0.5, 7.6, 1.7, 3.8, 0.8],
    ["Real estate and business services", "(%)", 19.6, 30.3, 23.6, 7.0, 4.5, 6.0, 5.5, 7.4, 6.3, 6.4, 6.0, 5.1],
    ["Other services", "(%)", 4.3, 5.2, 3.5, 3.5, 3.6, 4.0, 3.8, 3.2, 2.9, 3.2, 3.0, 2.9]
]

# Define the columns
columns = ["Indicator", "Unit", "2022_Q2r", "2022_Q3r", "2022_Q4r", "2023_Q1r", "2023_Q2r", "2023_Q3r", "2023_Q4r", "2024_Q1r", "2024_Q2r", "2024_Q3r", "2024_Q4r", "2025_Q1"]

# Create DataFrame
df = pd.DataFrame(data, columns=columns)

# Save to CSV
csv_path = os.path.join(output_dir, "labour_productivity_per_employment.csv")
df.to_csv("labour_productivity_per_employment.csv", index=False)

print("Saved CSV file: labour_productivity_per_employment.csv")
# Out:
# Saved CSV file: labour_productivity_per_employment.csv

# %%
# Creating CSV file for Total Hours Worked (Page 2)
import pandas as pd
import os

# Ensure output directory exists
output_path = "/mnt/data"
os.makedirs(output_path, exist_ok=True)

# Data for Total Hours Worked
data = {
    "Indicator": [
        "Total Hours Worked", "Agriculture", "Mining & Quarrying", "Manufacturing",
        "Vegetable and animal oils & fats and food processing", "Beverages and tobacco products",
        "Textiles, wearing apparel and leather products", "Wood products, furniture, paper products and printing",
        "Petroleum, chemical, rubber and plastic products", "Non-metallic mineral products, basic metal and fabricated metal products",
        "Electrical, electronic and optical products", "Transport equipment, other manufacturing and repair",
        "Construction", "Services", "Utilities", "Wholesale & retail trade",
        "Food & beverages and Accommodation", "Transportation and storage", "Information and communication",
        "Finance and insurance", "Real estate and business services", "Other services"
    ],
    "Unit": ["Million"] * 22,
    "2022_Q2r": [8939, 1002, 45, 1585, 275, 10, 144, 184, 263, 225, 368, 117, 814, 5493, 62, 1592, 954, 339, 149, 214, 670, 1512],
    "2022_Q3r": [9039, 1017, 46, 1595, 278, 11, 139, 186, 265, 227, 372, 117, 823, 5558, 63, 1618, 981, 346, 157, 209, 670, 1514],
    "2022_Q4r": [9210, 1000, 46, 1631, 285, 11, 136, 192, 267, 230, 387, 124, 827, 5706, 67, 1665, 995, 365, 164, 204, 711, 1536],
    "2023_Q1r": [9247, 1005, 46, 1637, 291, 11, 140, 188, 269, 230, 378, 129, 834, 5725, 65, 1644, 1041, 363, 156, 205, 715, 1536],
    "2023_Q2r": [9299, 1021, 47, 1652, 289, 11, 143, 193, 271, 228, 392, 124, 836, 5744, 65, 1653, 1045, 364, 158, 222, 704, 1533],
    "2023_Q3r": [9419, 1035, 46, 1669, 299, 10, 136, 200, 272, 234, 393, 125, 839, 5830, 66, 1653, 1088, 365, 160, 219, 717, 1562],
    "2023_Q4r": [9418, 1009, 47, 1674, 297, 12, 133, 199, 274, 238, 396, 126, 835, 5854, 67, 1653, 1094, 371, 164, 224, 713, 1568],
    "2024_Q1r": [9452, 1012, 47, 1674, 298, 13, 138, 192, 281, 233, 393, 128, 830, 5889, 66, 1681, 1086, 365, 163, 226, 726, 1577],
    "2024_Q2": [9612, 1034, 46, 1680, 305, 12, 141, 192, 285, 231, 388, 127, 823, 6028, 68, 1701, 1129, 375, 165, 225, 744, 1621],
    "2024_Q3r": [9672, 1033, 47, 1704, 309, 12, 142, 195, 287, 237, 393, 129, 838, 6050, 69, 1727, 1144, 375, 167, 230, 735, 1604],
    "2024_Q4r": [9747, 1022, 47, 1707, 310, 12, 136, 198, 281, 245, 399, 125, 849, 6122, 68, 1736, 1179, 382, 170, 228, 737, 1623],
    "2025_Q1": [9764, 1017, 46, 1697, 297, 12, 136, 194, 287, 248, 397, 125, 851, 6153, 69, 1744, 1191, 383, 167, 233, 747, 1618]
}

# Create DataFrame
df = pd.DataFrame(data)

# Save to CSV
csv_file_path = os.path.join(output_path, "total_hours_worked.csv")
df.to_csv("total_hours_worked.csv", index=False)

print("Saved 'total_hours_worked.csv' with Total Hours Worked data for all sectors and quarters.")
# Out:
# Saved 'total_hours_worked.csv' with Total Hours Worked data for all sectors and quarters.

# %%
# Creating CSV file for Total Employment data
import pandas as pd
import os

# Ensure output directory exists
output_dir = "/mnt/data"
os.makedirs(output_dir, exist_ok=True)

# Define the data
data = {
    "Indicator": [
        "Total Employment", "Agriculture", "Mining & Quarrying", "Manufacturing",
        "Vegetable and animal oils & fats and food processing", "Beverages and tobacco products",
        "Textiles, wearing apparel and leather products", "Wood products, furniture, paper products and printing",
        "Petroleum, chemical, rubber and plastic products", "Non-metallic mineral products, basic metal and fabricated metal products",
        "Electrical, electronic and optical products", "Transport equipment, other manufacturing and repair",
        "Construction", "Services", "Utilities", "Wholesale & retail trade",
        "Food & beverages and Accommodation", "Transportation and storage",
        "Information and communication", "Finance and insurance",
        "Real estate and business services", "Other services"
    ],
    "Unit": ["('000)"] * 22,
    "2022_Q2r": [15701, 1872, 76, 2705, 489, 18, 274, 304, 435, 374, 615, 195, 1383, 9666, 108, 2745, 1709, 566, 257, 373, 1152, 2756],
    "2022_Q3r": [15831, 1878, 76, 2731, 496, 18, 271, 309, 439, 376, 624, 197, 1378, 9768, 110, 2766, 1730, 576, 261, 376, 1169, 2781],
    "2022_Q4r": [15942, 1840, 76, 2740, 502, 18, 260, 308, 434, 379, 632, 207, 1387, 9899, 110, 2793, 1782, 595, 267, 378, 1176, 2797],
    "2023_Q1r": [16062, 1874, 76, 2771, 510, 19, 261, 312, 440, 383, 637, 210, 1391, 9949, 108, 2785, 1826, 600, 268, 381, 1183, 2797],
    "2023_Q2r": [16146, 1877, 76, 2780, 516, 19, 262, 318, 437, 379, 641, 207, 1397, 10017, 109, 2798, 1861, 603, 270, 381, 1187, 2809],
    "2023_Q3r": [16251, 1889, 76, 2814, 530, 19, 262, 324, 442, 388, 642, 208, 1398, 10074, 110, 2817, 1880, 604, 272, 382, 1190, 2818],
    "2023_Q4r": [16347, 1854, 76, 2823, 529, 19, 263, 326, 445, 392, 641, 208, 1403, 10190, 112, 2842, 1933, 610, 276, 385, 1197, 2835],
    "2024_Q1r": [16401, 1875, 76, 2820, 528, 19, 266, 322, 448, 390, 637, 209, 1406, 10224, 111, 2858, 1935, 616, 274, 387, 1199, 2843],
    "2024_Q2r": [16591, 1897, 76, 2825, 528, 19, 266, 322, 448, 390, 641, 211, 1408, 10385, 115, 2898, 1990, 630, 277, 390, 1222, 2862],
    "2024_Q3r": [16715, 1907, 76, 2853, 540, 19, 266, 326, 453, 397, 641, 211, 1410, 10468, 117, 2924, 2015, 633, 280, 390, 1233, 2877],
    "2024_Q4r": [16793, 1877, 77, 2861, 541, 19, 263, 331, 455, 400, 645, 208, 1415, 10563, 118, 2949, 2046, 638, 284, 391, 1237, 2899],
    "2025_Q1": [16893, 1881, 77, 2873, 543, 20, 270, 329, 455, 401, 645, 211, 1419, 10643, 117, 2979, 2065, 647, 284, 394, 1244, 2912]
}

# Create DataFrame
df = pd.DataFrame(data)

# Save to CSV
output_path = os.path.join(output_dir, "total_employment.csv")
df.to_csv("total_employment.csv", index=False)

print("Saved Total Employment data to total_employment.csv")
# Out:
# Saved Total Employment data to total_employment.csv

# %%
# Creating CSV file for GDP at constant 2015 prices (Page 4)
import pandas as pd
import os

# Ensure output directory exists
output_dir = "/mnt/data"
os.makedirs(output_dir, exist_ok=True)

# Define the data
data = [
    ["GDP at constant 2015 prices", "Million", 369429, 386820, 398919, 381857, 379286, 398768, 410231, 397802, 401672, 420354, 430477, 415224],
    ["Agriculture", "Million", 23647, 28022, 25566, 23128, 23364, 28039, 25862, 23576, 25139, 29060, 25683, 23709],
    ["Mining & Quarrying", "Million", 23667, 23422, 25536, 25112, 23143, 22944, 26338, 26203, 23776, 22295, 26158, 25492],
    ["Manufacturing", "Million", 89063, 92431, 95536, 90008, 89171, 92325, 95290, 91864, 93387, 97455, 99328, 95676],
    ["Vegetable and animal oils & fats and food processing", "Million", 8344, 8871, 8618, 7626, 8522, 9235, 9245, 7620, 8947, 9937, 9827, 8321],
    ["Beverages and tobacco products", "Million", 2570, 2099, 2238, 2225, 2795, 2194, 2359, 2373, 3017, 2411, 2548, 2447],
    ["Textiles, wearing apparel and leather products", "Million", 1478, 1513, 1574, 1619, 1533, 1519, 1573, 1645, 1589, 1589, 1581, 1662],
    ["Wood products, furniture, paper products and printing", "Million", 5728, 5433, 5564, 5973, 5646, 5470, 5775, 6225, 5939, 5827, 6035, 6420],
    ["Petroleum, chemical, rubber and plastic products", "Million", 24254, 28285, 26637, 24177, 23857, 27600, 26472, 24483, 24832, 28815, 27287, 25112],
    ["Non-metallic mineral products, basic metal and fabricated metal products", "Million", 9015, 8919, 9596, 9476, 9506, 9406, 10196, 10174, 10398, 10269, 10629, 10536],
    ["Electrical, electronic and optical products", "Million", 28784, 29615, 31063, 31302, 28364, 28861, 29191, 31569, 29219, 30486, 31293, 34027],
    ["Transport equipment, other manufacturing and repair", "Million", 8889, 7696, 10245, 7609, 8949, 8038, 10479, 7776, 9446, 8120, 10127, 7150],
    ["Construction", "Million", 12973, 13626, 13912, 13896, 13778, 14599, 14390, 15555, 16141, 17512, 17371, 17760],
    ["Services", "Million", 215854, 225150, 233791, 225405, 225308, 236338, 243312, 236130, 238584, 248734, 256662, 247887],
    ["Utilities", "Million", 10084, 10325, 10278, 9782, 10438, 10539, 10729, 10491, 10770, 10870, 10852, 10367],
    ["Wholesale & retail trade", "Million", 63983, 69007, 72615, 66207, 66897, 72817, 75792, 68816, 69993, 75832, 79103, 71808],
    ["Food & beverages and Accommodation", "Million", 10822, 11201, 11552, 11579, 11568, 11818, 12054, 12202, 12263, 12546, 12908, 13050],
    ["Transportation and storage", "Million", 13704, 14091, 14516, 15015, 15554, 15890, 16326, 16717, 17155, 17568, 18071, 18300],
    ["Information and communication", "Million", 24775, 25019, 25104, 25512, 25685, 25896, 25926, 26254, 26474, 26803, 26987, 27194],
    ["Finance and insurance", "Million", 25878, 26662, 27045, 27012, 24501, 26411, 25657, 27245, 27021, 27382, 27044, 28013],
    ["Real estate and business services", "Million", 16441, 16842, 17314, 17409, 17705, 18164, 18602, 18950, 19375, 20022, 20361, 20676],
    ["Other services", "Million", 50166, 52002, 55365, 52889, 52961, 54802, 58227, 55456, 55533, 57712, 61337, 58479],
    ["plus import duties", "Million", 4224, 4168, 4579, 4308, 4522, 4523, 5040, 4474, 4645, 5298, 5275, 4699]
]

# Define column names
columns = ["Indicator", "Unit", "2022_Q2r", "2022_Q3r", "2022_Q4r", "2023_Q1r", "2023_Q2r", "2023_Q3r", "2023_Q4r", "2024_Q1r", "2024_Q2r", "2024_Q3r", "2024_Q4r", "2025_Q1"]

# Create DataFrame
df = pd.DataFrame(data, columns=columns)

# Save to CSV
output_path = os.path.join(output_dir, "gdp_constant_2015_prices.csv")
df.to_csv("gdp_constant_2015_prices.csv", index=False)

print("Saved GDP at constant 2015 prices data to gdp_constant_2015_prices.csv")
# Out:
# Saved GDP at constant 2015 prices data to gdp_constant_2015_prices.csv

# %%
# Creating CSV file for GDP Annual Percentage Change (Page 5)
import os
import pandas as pd

# Ensure output directory exists
output_dir = "/mnt/data"
os.makedirs(output_dir, exist_ok=True)

# Define data
data = [
    ["GDP at constant 2015 prices", "(%)", 9.2, 14.6, 7.4, 5.7, 2.7, 3.1, 2.8, 4.2, 5.9, 5.4, 4.9, 4.4],
    ["Agriculture", "(%)", -1.7, 2.6, 2.6, 0.9, -1.2, 0.1, 1.2, 1.9, 7.6, 3.6, -0.7, 0.6],
    ["Mining & Quarrying", "(%)", -1.7, 10.4, 7.3, 3.0, -2.2, -2.0, 3.1, 4.3, 2.7, -2.8, -0.7, -2.7],
    ["Manufacturing", "(%)", 9.3, 13.2, 4.0, 3.2, 0.1, -0.1, -0.3, 2.1, 4.7, 5.6, 4.2, 4.1],
    ["Vegetable and animal oils & fats and food processing", "(%)", 2.8, 5.6, 4.6, 7.1, 2.1, 4.1, 7.3, -0.1, 5.0, 7.6, 6.3, 9.2],
    ["Beverages and tobacco products", "(%)", 28.2, 49.4, -4.4, 5.5, 8.7, 4.5, 5.4, 6.6, 7.9, 9.9, 8.0, 3.1],
    ["Textiles, wearing apparel and leather products", "(%)", 7.1, 12.3, -0.3, 0.8, 3.7, 0.4, -0.1, 1.6, 3.6, 4.6, 0.5, 1.1],
    ["Wood products, furniture, paper products and printing", "(%)", 12.1, 15.7, -2.7, -4.0, -1.4, 0.7, 3.8, 4.2, 5.2, 6.5, 4.5, 3.1],
    ["Petroleum, chemical, rubber and plastic products", "(%)", -0.8, 4.3, 1.0, 1.8, -1.6, -2.4, -0.6, 1.3, 4.1, 4.4, 3.1, 2.6],
    ["Non-metallic mineral products, basic metal and fabricated metal products", "(%)", 10.5, 13.6, 2.1, 3.5, 5.4, 5.5, 6.2, 7.4, 9.4, 9.2, 4.3, 3.6],
    ["Electrical, electronic and optical products", "(%)", 15.5, 17.4, 9.2, 3.8, -1.5, -2.5, -6.0, 0.9, 3.0, 5.6, 7.2, 7.8],
    ["Transport equipment, other manufacturing and repair", "(%)", 20.4, 37.2, 5.0, 7.7, 0.7, 4.5, 2.3, 2.2, 5.6, 1.0, -3.4, -8.0],
    ["Construction", "(%)", 2.7, 15.2, 10.3, 7.4, 6.2, 7.1, 3.4, 11.9, 17.2, 20.0, 20.7, 14.2],
    ["Services", "(%)", 12.6, 17.2, 9.3, 7.3, 4.4, 5.0, 4.1, 4.8, 5.9, 5.2, 5.5, 5.0],
    ["Utilities", "(%)", 3.9, 7.9, 0.5, 0.7, 3.5, 2.1, 4.4, 7.3, 3.2, 3.1, 1.1, -1.2],
    ["Wholesale & retail trade", "(%)", 17.8, 24.5, 9.8, 9.7, 4.6, 5.5, 4.4, 3.9, 4.6, 4.1, 4.4, 4.3],
    ["Food & beverages and Accommodation", "(%)", 39.4, 54.0, 25.2, 12.2, 6.9, 5.5, 4.3, 5.4, 6.0, 6.2, 7.1, 6.9],
    ["Transportation and storage", "(%)", 37.1, 42.2, 19.9, 16.0, 13.5, 12.8, 12.5, 11.3, 10.3, 10.6, 10.7, 9.5],
    ["Information and communication", "(%)", 5.9, 4.3, 4.3, 3.8, 3.7, 3.5, 3.3, 2.9, 3.1, 3.5, 4.1, 3.6],
    ["Finance and insurance", "(%)", -1.6, 3.5, 1.0, 1.7, -5.3, -0.9, -5.1, 0.9, 10.3, 3.7, 5.4, 2.8],
    ["Real estate and business services", "(%)", 22.8, 36.5, 28.6, 11.5, 7.7, 7.9, 7.4, 8.8, 9.4, 10.2, 9.5, 9.1],
    ["Other services", "(%)", 7.2, 8.6, 6.5, 5.8, 5.6, 5.4, 5.2, 4.9, 4.9, 5.3, 5.3, 5.5]
]

# Define columns
columns = ["Indicator", "Unit", "2022_Q2r", "2022_Q3r", "2022_Q4r", "2023_Q1r", "2023_Q2r", "2023_Q3r", "2023_Q4r", "2024_Q1r", "2024_Q2r", "2024_Q3r", "2024_Q4r", "2025_Q1"]

# Create DataFrame and save to CSV
df = pd.DataFrame(data, columns=columns)
csv_path = os.path.join(output_dir, "gdp_annual_percentage_change.csv")
df.to_csv("gdp_annual_percentage_change.csv", index=False)

print("Created CSV file for GDP Annual Percentage Change: gdp_annual_percentage_change.csv")
# Out:
# Created CSV file for GDP Annual Percentage Change: gdp_annual_percentage_change.csv
